# %% [markdown]
# # Minitools

# %% [markdown]
# ## Hashtrag Creator for Instagram-/YT-Shorts-/TikTok-Posts

# %% [markdown]
# ### Input

# %%
songs = """JIHYO - Closer
tripleS AAA - Generation
ENHYPEN - Criminal Love
EVNNE - TROUBLE
TXT - Chasing That Feeling
NCT 127 - Fact Check
aespa - Drama
iKON - KILLING ME
P1Harmony - Butterfly"""

# %% [markdown]
# ### Output

# %%
songs_list = songs.split("\n")
song_split = []
for x in range(len(songs_list)):
    hashtags = []
    song_split.append([])
    for y in range(2):
        song_split[x].append(''.join(e for e in songs_list[x].split(" - ")[y] if e.isalnum()).lower())
    hashtags.append(f"#{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][0]}{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}dancecover")
    hashtags.append(f"#{song_split[x][0]}edit")
    print(" ".join(hashtags))
# Out:
# #jihyo #closer #closerjihyo #jihyocloser #closerdancecover #jihyoedit
# #triplesaaa #generation #generationtriplesaaa #triplesaaageneration #generationdancecover #triplesaaaedit
# #enhypen #criminallove #criminalloveenhypen #enhypencriminallove #criminallovedancecover #enhypenedit
# #evnne #trouble #troubleevnne #evnnetrouble #troubledancecover #evnneedit
# #txt #chasingthatfeeling #chasingthatfeelingtxt #txtchasingthatfeeling #chasingthatfeelingdancecover #txtedit
# #nct127 #factcheck #factchecknct127 #nct127factcheck #factcheckdancecover #nct127edit
# #aespa #drama #dramaaespa #aespadrama #dramadancecover #aespaedit
# #ikon #killingme #killingmeikon #ikonkillingme #killingmedancecover #ikonedit
# #p1harmony #butterfly #butterflyp1harmony #p1harmonybutterfly #butterflydancecover #p1harmonyedit

# %% [markdown]
# ## Hashtag Creator for YT Video + Artist/Title Lister

# %% [markdown]
# ### Input (YT Timestamps)

# %%
raw = """00:00:03 1 P1Harmony - SAD SONG (Chorus 1) (None)
00:01:15 2 GOT7 - Hard Carry (Chorus 1) (None)
00:02:10 3 MONSTA X - Oh My! (Chorus 1) (None)
00:03:02 4 Twice - Fancy (Pre-Chorus 1, Chorus 1) (None)
00:03:51 5 Kwon Yuri - Into You (None) (None)
00:04:45 6 WayV - Frequency (None) (None)
00:05:55 7 TWS - Last Festival (Chorus 1) (None)
00:07:01 8 xikers - we don’t stop (Chorus 2, Dancebreak) (None)
00:08:42 9 Baekhyun - R U Ridin (Chorus 1) (None)
00:09:33 10 Kiss Of Life - Get Loud (Chorus 2, Dancebreak) (None)
00:11:08 11 EXO - Going Crazy (None) (None)
00:12:06 12 Chung Ha - Gotta Go (Chorus 1) (None)
00:13:06 13 BOYNEXTDOOR - Nice guy (Chorus 2, Dancebreak) (None)
00:14:11 14 Rocket Punch - Chiquita (Chorus 1) (None)
00:15:05 15 (G)I-DLE - Nxde (Chorus 1) (None)
00:15:58 16 Enhypen - Fatal Trouble (Chorus 1) (None)
00:17:15 17 Stray Kids - Back Door (Chorus 1) (None)
00:17:56 18 Yves - Viola (Chorus 1) (None)
00:18:33 19 NCT - Zoo (Chorus 1) (None)
00:19:12 20 Project 7 - Run up to you (Dancebreak) (None)
00:20:54 21 SuperM - Jopping (Dancebreak) (None)
00:21:59 22 NCT U - Baby Don't Stop (Chorus 1) (None)
00:22:31 23 LOONA YEOJIN - Kiss Later (Chorus 1) (None)
00:23:21 24 Kep1er - Wa Da Da (Pre-Chorus 1, Chorus 1) (None)
00:24:20 25 JO1 - Rose (Chorus 1) (None)
00:25:17 26 Ateez - Bouncy (Chorus 1) (None)
00:26:10 27 Katseye - Debut (Chorus 1) (None)
00:26:53 28 Ive - Love Dive (Pre-Chorus 1, Chorus 1) (None)
00:28:00 29 WOODZ - FEEL LIKE (Chorus 2) (None)
00:28:48 30 SEVENTEEN - LOVE, MONEY, FAME (Chorus 1) (None)
00:30:03 31 Itzy - Escalator (Chorus 1) (None)
00:31:07 32 GHOST9 - Monster (Chorus 2) (None)
00:32:10 33 Jaehyun - Unconditional (Chorus 1) (None)
00:33:12 34 Dal Shabet - Someone Like You (Chorus 1) (None)
00:34:07 35 4Minute - Crazy (Chorus 1) (None)
00:34:53 36 THE BOYZ - Bite Back (Chorus 1) (None)
00:35:44 37 Babymonster - Drip (Chorus 2) (None)"""

# %% [markdown]
# ### Output

# %% [markdown]
# #### Hashtags for YT Video

# %%
raw_list = raw.split("\n")

export_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_edit = "".join(e for e in artist if e.isalnum()).upper()
    export_list.append(artist_edit)

export_list.sort()
export_list = list(dict.fromkeys(export_list))

artist_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_list.append(artist)

title_list = []
for x in raw_list:
    title = x.split(" - ")[1].split(" (")[0]
    title_list.append(title)

print("#" + " #".join(export_list))
# Out:
# #4MINUTE #82MAJOR #AESPA #ARRC #ATEEZ #BABYMONSTER #BADVILLAIN #BADVILLAN #BAE173 #BAEKHYUN #BI #BIBI #BILLLIE #BLACKPINK #BOYNEXTDOOR #BROWNEYEDGIRLS #BTS #BUS #CHUNGHA #CL #CLASSY #CLC #DALSHABET #DREAMCATCHER #ENHYPEN #EVERGLOW #EXID #EXO #FROMIS9 #GDRAGON #GHOST9 #GIDLE #GIRLSGENERATION #GIRLSPLANET999MEDUSA #GISELLE #GOT7 #HEEJIN #HELLOVENUS #ILLIT #ITZY #IVE #IZNA #IZONE #JAEHYUN #JENNIE #JISOO #JO1 #JUNGKOOK #KARD #KATSEYE #KEP1ER #KEY #KIMSEJEONG #KINGDOM #KISSOFLIFE #KWONEUNBI #KWONYURI #LESSERAFIM #LISA #LOONAYEOJIN #LUCAS #MISAMO #MOMOLAND #MONSTAX #MYTRO #NATURE #NAYEON #NCT #NCTDREAM #NCTU #NCTWISH #NEWJEANS #NUESTW #P1HARMONY #PENTAGON #PRISTINV #PROJECT7 #PSY #REDVELVET #RIIZE #ROCKETPUNCH #ROCKY #SECRETNUMBER #SEULGI #SEVENTEEN #SHINEE #STAYC #STRAYKIDS #SUNMI #SUPERM #TAEMIN #TAEYANG #TAEYONGTEN #THEBOYZ #TREASURE #TRIPLESVISIONARYVISION #TWICE #TWS #TXT #UKWON #VIVIZ #WAKER #WAYV #WINTER #WONDERGIRLS #WOODZ #XG #XIKERS #YENA #YOUNGPOSSE #YVES #ZEROBASEONE

# %% [markdown]
# #### Artist and Title

# %%
print("\n".join(artist_list))
print("\n\n\n\n\n\n")
print("\n".join(title_list))
# Out:
# Twice
# Jimin
# STAYC
# Yuto Adachi
# Stray Kids
# (G)I-DLE
# IVE
# LE SSERAFIM
# Got7
# (G)I-DLE
# f(x)
# NiziU
# 4Minute
# CRAVITY
# Kard
# Enhypen
# Red Velvet
# aespa
# Babymonster
# Dreamcatcher
# LE SSERAFIM
# Mamamoo
# Pentagon
# Ateez
# E'last
# Seventeen
# Itzy
# NMIXX
# Hwasa
# Taemin
# Twice
# 2PM
# (G)I-DLE
# Kep1er
# Blackpink
# TEN
# Exo
# NCT Wish
# Xdinary Heroes
# Alexa
# Brave Girls
# Stray Kids
# Billlie
# NCT 127
# Everglow
# Oneus
# aespa
# Iz*one
# 7 LOVE Minutes
# Itzy
# Chung Ha
# Enhypen
# Ghost9
# The Boyz
# VERIVERY
# Twice
# Weeekly
# (G)I-DLE
# Lee Suhyun
# Blackpink
# CRAVITY
# Produce 48
# Mamaoo
# Apink
# Itzy
# EXO
# Everglow
# TEN
# Stray Kids
# The Boyz
# Kep1er
# aespa
# NewJeans
# Enhypen
# OnlyOneOf
# VIVIZ
# P1harmony
# Girls Generation
# Kard
# BTS
# IZ*ONE
# Twice
# Enhypen
# LE SSERAFIM
# Stray Kids
# Itzy
# Somi
# Blackpink
# Babymonster
# Enhypen
# LE SSERAFIM
# JINI
# Red Velvet
# NMIXX
# ZEROBASEONE
# NMIXX
# (G)I-DLE
# Hinapia
# ...

# %% [markdown]
# ## Timestamp Creator for YT Video

# %% [markdown]
# ### Input

# %%
import math

startTime = "01:40:02"

raw = """
00:00:03 1 P1Harmony - SAD SONG (Chorus 1) (None)
00:01:15 2 GOT7 - Hard Carry (Chorus 1) (None)
00:02:10 3 MONSTA X - Oh My! (Chorus 1) (None)
00:03:02 4 Twice - Fancy (Pre-Chorus 1, Chorus 1) (None)
00:03:51 5 Kwon Yuri - Into You (None) (None)
00:04:45 6 WayV - Frequency (None) (None)
00:05:55 7 TWS - Last Festival (Chorus 1) (None)
00:07:01 8 xikers - we don’t stop (Chorus 2, Dancebreak) (None)
00:08:42 9 Baekhyun - R U Ridin (Chorus 1) (None)
00:09:33 10 Kiss Of Life - Get Loud (Chorus 2, Dancebreak) (None)
00:11:08 11 EXO - Going Crazy (None) (None)
00:12:06 12 Chung Ha - Gotta Go (Chorus 1) (None)
00:13:06 13 BOYNEXTDOOR - Nice guy (Chorus 2, Dancebreak) (None)
00:14:11 14 Rocket Punch - Chiquita (Chorus 1) (None)
00:15:05 15 (G)I-DLE - Nxde (Chorus 1) (None)
00:15:58 16 Enhypen - Fatal Trouble (Chorus 1) (None)|
00:17:15 17 Stray Kids - Back Door (Chorus 1) (None)
00:17:56 18 Yves - Viola (Chorus 1) (None)
00:18:33 19 NCT - Zoo (Chorus 1) (None)
00:19:12 20 Project 7 - Run up to you (Dancebreak) (None)
00:20:54 21 SuperM - Jopping (Dancebreak) (None)
00:21:59 22 NCT U - Baby Don't Stop (Chorus 1) (None)
00:22:31 23 LOONA YEOJIN - Kiss Later (Chorus 1) (None)
00:23:21 24 Kep1er - Wa Da Da (Pre-Chorus 1, Chorus 1) (None)
00:24:20 25 JO1 - Rose (Chorus 1) (None)
00:25:17 26 Ateez - Bouncy (Chorus 1) (None)
00:26:10 27 Katseye - Debut (Chorus 1) (None)
00:26:53 28 Ive - Love Dive (Pre-Chorus 1, Chorus 1) (None)
00:28:00 29 WOODZ - FEEL LIKE (Chorus 2) (None)
00:28:48 30 SEVENTEEN - LOVE, MONEY, FAME (Chorus 1) (None)
00:30:03 31 Itzy - Escalator (Chorus 1) (None)
00:31:07 32 GHOST9 - Monster (Chorus 2) (None)
00:32:10 33 Jaehyun - Unconditional (Chorus 1) (None)
00:33:12 34 Dal Shabet - Someone Like You (Chorus 1) (None)
00:34:07 35 4Minute - Crazy (Chorus 1) (None)
00:34:53 36 THE BOYZ - Bite Back (Chorus 1) (None)
00:35:44 37 Babymonster - Drip (Chorus 2) (None)
"""

# %% [markdown]
# ### Output

# %%
startTimeSplit = startTime.split(":")
startTimeInSeconds = 0
startTimeInSeconds += int(startTimeSplit[0]) * 60 * 60
startTimeInSeconds += int(startTimeSplit[1]) * 60
startTimeInSeconds += int(startTimeSplit[2])

rawSplit = raw.split("\n")[1:-1]
for x in rawSplit:
    playlistTimeStampInSeconds = 0
    newTimeStampHour = 0
    newTimeStampMinute = 0

    # Remove unnecassary Suffix
    noSuffix = x.rsplit(" (", 2)[0]
    noSuffixSplit = noSuffix.split(" ", 2)

    playlistTimeStampSplit = noSuffixSplit[0].split(":")
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[0]) * 60 * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[1]) * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[2])

    newTimeStampInSeconds = startTimeInSeconds + playlistTimeStampInSeconds

    newTimeStampHour =  math.floor(newTimeStampInSeconds / 3600)
    newTimeStampInSeconds = newTimeStampInSeconds % 3600
    newTimeStampHourString = str(newTimeStampHour).zfill(2)

    newTimeStampMinute =  math.floor(newTimeStampInSeconds / 60)
    newTimeStampInSeconds = newTimeStampInSeconds % 60
    newTimeStampMinuteString = str(newTimeStampMinute).zfill(2)

    newTimeStampSecondString =str(newTimeStampInSeconds).zfill(2)

    newTimeStampString = ":".join([newTimeStampHourString, newTimeStampMinuteString, newTimeStampSecondString])

    print(newTimeStampString + " " + noSuffixSplit[2])
# Out:
# 01:40:05 P1Harmony - SAD SONG
# 01:41:17 GOT7 - Hard Carry
# 01:42:12 MONSTA X - Oh My!
# 01:43:04 Twice - Fancy
# 01:43:53 Kwon Yuri - Into You
# 01:44:47 WayV - Frequency
# 01:45:57 TWS - Last Festival
# 01:47:03 xikers - we don’t stop
# 01:48:44 Baekhyun - R U Ridin
# 01:49:35 Kiss Of Life - Get Loud
# 01:51:10 EXO - Going Crazy
# 01:52:08 Chung Ha - Gotta Go
# 01:53:08 BOYNEXTDOOR - Nice guy
# 01:54:13 Rocket Punch - Chiquita
# 01:55:07 (G)I-DLE - Nxde
# 01:56:00 Enhypen - Fatal Trouble
# 01:57:17 Stray Kids - Back Door
# 01:57:58 Yves - Viola
# 01:58:35 NCT - Zoo
# 01:59:14 Project 7 - Run up to you
# 02:00:56 SuperM - Jopping
# 02:02:01 NCT U - Baby Don't Stop
# 02:02:33 LOONA YEOJIN - Kiss Later
# 02:03:23 Kep1er - Wa Da Da
# 02:04:22 JO1 - Rose
# 02:05:19 Ateez - Bouncy
# 02:06:12 Katseye - Debut
# 02:06:55 Ive - Love Dive
# 02:08:02 WOODZ - FEEL LIKE
# 02:08:50 SEVENTEEN - LOVE, MONEY, FAME
# 02:10:05 Itzy - Escalator
# 02:11:09 GHOST9 - Monster
# ...

# %% [markdown]
# # Caption Generator (for Now Playing)

# %%
raw = """
00:00:09 Kingdom - Long live the king
00:01:05 (G)I-DLE - Tomboy
00:02:36 ARrC - S&S (sour and sweet)
00:03:38 Young Posse - Ate That
00:04:38 Riize - Boom Boom Bass
00:06:09 KARD - Icky
00:07:07 BUS - LIAR
00:07:51 Stayc - GPT
00:08:53 Viviz - Shhh!
00:09:59 Twice - Doughnut
00:10:49 Kep1er - Tipi-Tap
00:11:37 Pristin V - Get it
00:12:12 NCT DREAM - When I‘m With You
00:12:59 Momoland - Bboom Bboom
00:13:59 Wonder Girls - Tell Me
00:14:50 G-DRAGON - HOME SWEET HOME
00:15:45 EXID - I Love You
00:16:48 Giselle - Dopamine
00:17:28 Sunmi - Lalalay
00:18:17 BAE173 - get him UGH
00:19:11 WAKER - Vanilla Choco Shake
00:20:31 NAYEON - ABCD
00:21:20 Seulgi - 28 Reasons
00:22:27 ILLIT - Tick-Tack
00:23:16 Taeyong & Ten - Swipe
00:23:56 Blackpink - Ddu-Du Ddu-du
00:24:34 NU'EST W - Deja Vu
00:25:50 Enhypen - Drunk-Dazed
00:26:43 xikers - bittersweet
00:28:24 Lisa - Rockstar
00:29:05 CLC - Me
00:29:51 B.I - BTBT
00:30:32 Kwon Eunbi - Glitch
00:31:45 JO1 - ICY
00:32:43 IzOne - La vie en rose
00:33:36 Twice - What is Love
00:34:16 Itzy - Wannabe
00:35:24 KEY - Tongue Tied
00:36:25 Izna - IZNA
00:37:01 Xikers - Witch
00:37:50 JO1 - Tiger
00:38:47 Dreamcatcher - Vision
00:39:53 Psy - That That
00:40:50 Twice - Go Hard
00:41:24 Enhypen - Moonstruck
00:42:21 CL - Spicy
00:43:29 XG - Howling
00:44:29 P1HARMONY - Scared
00:45:05 Le Sserafim - Antifragile
00:45:59 Kep1er - Shooting star
00:46:39 BIBI - Vengeance 
00:47:41 82major - Stuck
00:48:13 Nct Dream - Boom
00:49:03 Girls Planet 999 (Medusa) - Snake
00:50:10 HEEJIN - Video Game
00:50:58 ZeroBaseOne - Good so Bad
00:51:41 lucas - Renegade
00:52:36 Jennie - Mantra
00:53:15 Treasure - Move
00:54:39 MYTRO - Bomb Bomb Bomb
00:55:40 NCT WISH - Steady
00:56:32 BADVILLAIN - 82
00:57:24 Stray Kids - Thunderous
00:58:12 EXO - Love Shot
00:59:07 Taemin - Move
00:59:54 (G)I-DLE - Senorita
01:00:40 ITZY - GOLD
01:01:22 Rocky - Jealousy
01:02:29 Kiss Of Life - Igloo
01:03:18 Shinee - Ring Ding Dong
01:03:52 txt - Heaven
01:04:31 Winter - Spark
01:05:29 Brown eyed girls - Abracadabra
01:06:30 ATEEZ - Ice On My Teeth
01:07:31 Red velvet - Cosmic
01:08:33 U- Kwon - Tough Love
01:09:24 WINTER - Spark
01:10:30 Jisoo - Flower
01:11:08 Kep1er - sync-love
01:12:08 Ateez - Ice On My Teeth
01:13:11 BADVILLAN - ZOOM
01:13:56 Taeyang - Ringa Linga
01:14:35 YENA - NEMONEMO
01:15:32 BTS - Go Go
01:16:48 Le Sserafim - Eve, Psyche & the Bluebeards Wife
01:17:47 CLASS:y - Psycho and beautiful
01:18:38 Kim Se Jeong - Top or Cliff
01:19:39 Enhypen - Criminal Love
01:20:33 Xg - Iykyk
01:21:15 Stray Kids - Walkin on Water
01:21:56 HELLOVENUS - Wiggle Wiggle
01:22:38 BILLLIE - Remembrance candy
01:23:22 Secret number - Starlight
01:24:25 NCT DREAM - ISTJ
01:25:09 Twice - Strategy
01:25:57 Everglow - Adios
01:26:55 TripleS Visionary Vision - Hit the Floor
01:27:39 Girls’ Generation - Mr.Mr.
01:28:46 Nature - Limbo
01:29:58 Pentagon - Shine
01:30:43 Aespa - Whiplash
01:31:31 Misamo - Identity
01:32:30 Itzy - Imaginary friend
01:33:40 fromis_9 - #menow
01:34:22 Jungkook - Standing next to you
01:35:49 NewJeans - Attention
01:36:31 IZNA - Timebomb
01:37:26 Kiss of Life - Nobody Knows
01:38:25 Shinee - Sherlock
01:39:05 (G)I-DLE - Tomboy
01:40:05 P1Harmony - SAD SONG
01:41:17 GOT7 - Hard Carry
01:42:12 MONSTA X - Oh My!
01:43:04 Twice - Fancy
01:43:53 Kwon Yuri - Into You
01:44:47 WayV - Frequency
01:45:57 TWS - Last Festival
01:47:03 xikers - we don’t stop
01:48:44 Baekhyun - R U Ridin
01:49:35 Kiss Of Life - Get Loud
01:51:10 EXO - Going Crazy
01:52:08 Chung Ha - Gotta Go
01:53:08 BOYNEXTDOOR - Nice guy
01:54:13 Rocket Punch - Chiquita
01:55:07 (G)I-DLE - Nxde
01:56:00 Enhypen - Fatal Trouble
01:57:17 Stray Kids - Back Door
01:57:58 Yves - Viola
01:58:35 NCT - Zoo
01:59:14 Project 7 - Run up to you
02:00:56 SuperM - Jopping
02:02:01 NCT U - Baby Don't Stop
02:02:33 LOONA YEOJIN - Kiss Later
02:03:23 Kep1er - Wa Da Da
02:04:22 JO1 - Rose
02:05:19 Ateez - Bouncy
02:06:12 Katseye - Debut
02:06:55 Ive - Love Dive
02:08:02 WOODZ - FEEL LIKE
02:08:50 SEVENTEEN - LOVE, MONEY, FAME
02:10:05 Itzy - Escalator
02:11:09 GHOST9 - Monster
02:12:12 Jaehyun - Unconditional
02:13:14 Dal Shabet - Someone Like You
02:14:09 4Minute - Crazy
02:14:55 THE BOYZ - Bite Back
02:15:46 Babymonster - Drip
"""
rawSplit = raw.split("\n")[1:-1]

timestamp_end_of_video = "02:16:29"
rawSplit.append(f"{timestamp_end_of_video} End")

print(rawSplit)
# Out:
# ['00:00:09 Kingdom - Long live the king', '00:01:05 (G)I-DLE - Tomboy', '00:02:36 ARrC - S&S (sour and sweet)', '00:03:38 Young Posse - Ate That', '00:04:38 Riize - Boom Boom Bass', '00:06:09 KARD - Icky', '00:07:07 BUS - LIAR', '00:07:51 Stayc - GPT', '00:08:53 Viviz - Shhh!', '00:09:59 Twice - Doughnut', '00:10:49 Kep1er - Tipi-Tap', '00:11:37 Pristin V - Get it', '00:12:12 NCT DREAM - When I‘m With You', '00:12:59 Momoland - Bboom Bboom', '00:13:59 Wonder Girls - Tell Me', '00:14:50 G-DRAGON - HOME SWEET HOME', '00:15:45 EXID - I Love You', '00:16:48 Giselle - Dopamine', '00:17:28 Sunmi - Lalalay', '00:18:17 BAE173 - get him UGH', '00:19:11 WAKER - Vanilla Choco Shake', '00:20:31 NAYEON - ABCD', '00:21:20 Seulgi - 28 Reasons', '00:22:27 ILLIT - Tick-Tack', '00:23:16 Taeyong & Ten - Swipe', '00:23:56 Blackpink - Ddu-Du Ddu-du', "00:24:34 NU'EST W - Deja Vu", '00:25:50 Enhypen - Drunk-Dazed', '00:26:43 xikers - bittersweet', '00:28:24 Lisa - Rockstar', '00:29:05 CLC - Me', '00:29:51
# ...

# %%
timestamp_end_of_video = "02:16:29"
caption_text = """1
00:00:00,000 --> 00:00:09,000
RDG Start\n\n"""
count = 0
timestamp_old = rawSplit[0].split(" ")[0]
for x in range(len(rawSplit)-1):
    caption_text += f"{x+1}\n"

    timestamp_next = rawSplit[x+1].split(" ")[0]
    caption_text += f"{timestamp_old},000 --> {timestamp_next},000\n"
    timestamp_old = timestamp_next

    # Remove unnecassary Suffix
    noSuffixSplit = rawSplit[x].split(" ", 1)
    caption_text += f"{noSuffixSplit[1]}\n\n"
    
print(caption_text)
# Out:
# 1
# 00:00:00,000 --> 00:00:09,000
# RDG Start
#
# 1
# 00:00:09,000 --> 00:01:05,000
# Kingdom - Long live the king
#
# 2
# 00:01:05,000 --> 00:02:36,000
# (G)I-DLE - Tomboy
#
# 3
# 00:02:36,000 --> 00:03:38,000
# ARrC - S&S (sour and sweet)
#
# 4
# 00:03:38,000 --> 00:04:38,000
# Young Posse - Ate That
#
# 5
# 00:04:38,000 --> 00:06:09,000
# Riize - Boom Boom Bass
#
# 6
# 00:06:09,000 --> 00:07:07,000
# KARD - Icky
#
# 7
# 00:07:07,000 --> 00:07:51,000
# BUS - LIAR
#
# 8
# 00:07:51,000 --> 00:08:53,000
# Stayc - GPT
#
# 9
# 00:08:53,000 --> 00:09:59,000
# Viviz - Shhh!
#
# 10
# 00:09:59,000 --> 00:10:49,000
# Twice - Doughnut
#
# 11
# 00:10:49,000 --> 00:11:37,000
# Kep1er - Tipi-Tap
#
# 12
# 00:11:37,000 --> 00:12:12,000
# Pristin V - Get it
#
# 13
# 00:12:12,000 --> 00:12:59,000
# NCT DREAM - When I‘m With You
#
# 14
# 00:12:59,000 --> 00:13:59,000
# Momoland - Bboom Bboom
#
# 15
# 00:13:59,000 --> 00:14:50,000
# Wonder Girls - Tell Me
#
# 16
# 00:14:50,000 --> 00:15:45,000
# ...

# %% [markdown]
# # Playground

# %%
import json
import yt_dlp

URL = 'https://www.youtube.com/watch?v=BaW_jenozKc'

# ℹ️ See help(yt_dlp.YoutubeDL) for a list of available options and public functions
ydl_opts = {}
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(URL, download=False)

    # ℹ️ ydl.sanitize_info makes the info json-serializable
    print(info['title'])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BaW_jenozKc
# [youtube] BaW_jenozKc: Downloading webpage
# [youtube] BaW_jenozKc: Downloading ios player API JSON
# [youtube] BaW_jenozKc: Downloading android player API JSON
# ERROR: [youtube] BaW_jenozKc: Video unavailable. This video has been removed by the uploader
# ---------------------------------------------------------------------------
# ExtractorError                            Traceback (most recent call last)
# File d:\Documents\Code\rdg_maker_backend\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1594, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1593 try:
# -> 1594     return func(self, *args, **kwargs)
#    1595 except (DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#
# File d:\Documents\Code\rdg_maker_backend\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1729, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1728 try:
# ...

# %%
raw = """00:00:03 1 tripleS - Girls never die (Chorus 2) (Mel)
00:00:36 2 TXT - Chasing that Feeling (Chorus) (Basic)
00:01:11 3 Iz*One - Panorama (Chorus) (Alissa)
00:01:57 4 Ill'it - Magnetic (Chorus) (Basic)
00:02:37 5 StrayKids - God's Menu (Pre-Chorus, Chorus) (Basic)
00:03:21 6 Han Seungwoo - Sacrifice (Chorus 2) (Ace)
00:04:01 7 EXO - Ooh La La La (Chorus) (Adriana)
00:04:34 8 Kiss of Life - Midas Touch (Pre-Chorus, Chorus) (Milla)
00:05:06 9 &Team - Samidare (Chorus) (Salina)
00:05:58 10 Ateez - Horizon (Chorus) (Yuki)
00:06:26 11 Billie - Gingamingayo (Chorus) (Yuki)
00:07:17 12 (G)-idle - Wife (Pre-Chorus, Chorus 2) (Lilly)
00:08:00 13 NCT U - Baby don't stop (Chorus) (Mel)
00:08:34 14 Loossemble - ‘Girls’ Night’ (Dancebreak) (Salina)
00:09:28 15 Twice - MORE & MORE (Dancebreak) (Ines)
00:10:15 16 Aespa - Drama (Chorus) (Basic)
00:10:56 17 Enhypen - Bite me (Dancebreak) (Ivan)
00:11:48 18 Bts - Fire (Chorus) (Thony)
00:12:32 19 Everglow - Bon Bon Chocolat (Chorus) (Basic)
00:13:19 20 KARD - Icky (Chorus) (Basic)
00:13:55 21 JungKook - Standing Next To You (Dancebreak) (Basic)
00:14:42 22 IVE - I Am (Chorus) (Basic)
00:15:08 23 Xikers - Tricky House (Dancebreak) (Basic)
00:15:38 24 Taemin - Advice (Chorus) (Jake)
00:16:27 25 Enhypen - mixed up (Pre-Chorus, Chorus) (Marry)
00:17:13 26 Seventeen - Left & Right (Chorus) (Ace)
00:17:57 27 PSY - Gangnam Style (Chorus) (Basic)
00:18:35 28 Boynextdoor - Earth, Wind & Fire (Chorus) (Milla)
00:19:07 29 VCHA - Only One (Pre-Chorus, Chorus) (Alessa)
00:19:59 30 Itzy - Loco (Chorus) (Basic)
00:20:36 31 Chung Ha  - Snapping (Chorus) (Basic)
00:21:20 32 Soñar (Breaker) - NMIXX (Chorus 2, Dancebreak) (Lera)
00:22:33 33 WayV - Regular (Chorus) (Ascela)
00:23:12 34 NCT 127 - Kick it (Intro) (Basic)
00:23:49 35 OMEGAX - JUNK FOOD (Pre-Chorus, Chorus) (Marry)
00:24:23 36 Babymonster - Sheesh (Pre-Chorus, Chorus) (Hanna)"""

# %%
arr = raw.split("\n")
sec = 0
for x in arr:
    temp = x.split(" ")[0].split(":")
    sec = int(temp[2]) + (int(temp[1]) * 60) + (int(temp[0]) * 360)
    print(sec)
# Out:
# 3
# 36
# 71
# 117
# 157
# 201
# 241
# 274
# 306
# 358
# 386
# 437
# 480
# 514
# 568
# 615
# 656
# 708
# 752
# 799
# 835
# 882
# 908
# 938
# 987
# 1033
# 1077
# 1115
# 1147
# 1199
# 1236
# 1280
# 1353
# 1392
# 1429
# 1463
