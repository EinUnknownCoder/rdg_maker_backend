# %% [markdown]
# # Minitools

# %% [markdown]
# ## Hashtrag Creator for Instagram-/YT-Shorts-/TikTok-Posts

# %% [markdown]
# ### Input

# %%
songs = """JIHYO - Closer
tripleS AAA - Generation
ENHYPEN - Criminal Love
EVNNE - TROUBLE
TXT - Chasing That Feeling
NCT 127 - Fact Check
aespa - Drama
iKON - KILLING ME
P1Harmony - Butterfly"""

# %% [markdown]
# ### Output

# %%
songs_list = songs.split("\n")
song_split = []
for x in range(len(songs_list)):
    hashtags = []
    song_split.append([])
    for y in range(2):
        song_split[x].append(''.join(e for e in songs_list[x].split(" - ")[y] if e.isalnum()).lower())
    hashtags.append(f"#{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][0]}{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}dancecover")
    hashtags.append(f"#{song_split[x][0]}edit")
    print(" ".join(hashtags))
# Out:
# #jihyo #closer #closerjihyo #jihyocloser #closerdancecover #jihyoedit
# #triplesaaa #generation #generationtriplesaaa #triplesaaageneration #generationdancecover #triplesaaaedit
# #enhypen #criminallove #criminalloveenhypen #enhypencriminallove #criminallovedancecover #enhypenedit
# #evnne #trouble #troubleevnne #evnnetrouble #troubledancecover #evnneedit
# #txt #chasingthatfeeling #chasingthatfeelingtxt #txtchasingthatfeeling #chasingthatfeelingdancecover #txtedit
# #nct127 #factcheck #factchecknct127 #nct127factcheck #factcheckdancecover #nct127edit
# #aespa #drama #dramaaespa #aespadrama #dramadancecover #aespaedit
# #ikon #killingme #killingmeikon #ikonkillingme #killingmedancecover #ikonedit
# #p1harmony #butterfly #butterflyp1harmony #p1harmonybutterfly #butterflydancecover #p1harmonyedit

# %% [markdown]
# ## Hashtag Creator for YT Video + Artist/Title Lister

# %% [markdown]
# ### Input (YT Timestamps)

# %%
raw = """00:00:03 1 Twice - Like OOH-AHH (None) (None)
00:00:44 2 Jimin - Set Me Free Pt. 2 (None) (None)
00:01:44 3 STAYC - Teddy Bear (None) (None)
00:02:29 4 Yuto Adachi - Poker (None) (None)
00:03:22 5 Stray Kids - Taste (None) (None)
00:04:10 6 (G)I-DLE - Wife (None) (None)
00:04:54 7 IVE - Kitsch (None) (None)
00:05:44 8 LE SSERAFIM - Fearless (None) (None)
00:06:31 9 Got7 - Just Right (None) (None)
00:07:25 10 (G)I-DLE - Nxde (None) (None)
00:08:10 11 f(x)  - Electric Shock (None) (None)
00:08:40 12 NiziU - Heartris (None) (None)
00:09:33 13 4Minute - Crazy (None) (None)
00:10:24 14 CRAVITY - Gas Pedal (None) (None)
00:11:35 15 Kard - Cake (None) (None)
00:12:10 16 Enhypen  - Sacrifice (Eat me up)  (None) (None)
00:12:58 17 Red Velvet - Dumb Dumb (None) (None)
00:13:52 18 aespa - Black Mamba (None) (None)
00:14:33 19 Babymonster - Batter Up (None) (None)
00:15:07 20 Dreamcatcher - OOTD (None) (None)
00:15:46 21 LE SSERAFIM - Unforgiven (None) (None)
00:13:37 18 Pentagon - Dr. Bebe (None) (None)
00:14:34 19 STARSEED'Z - ICONIC (None) (None)
00:15:12 20 Enhypen - Fever (None) (None)
00:15:58 21 Itzy - UNTOUCHABLE (None) (None)
00:16:56 22 S.I.S - Always be your Girl (None) (None)
00:17:39 23 Ateez - Crazy Form (None) (None)
00:18:10 24 WAYV - Turn Back Time (None) (None)
00:18:51 25 B.I - BTBT (None) (None)
00:19:22 26 Hwasa - I'm a B (None) (None)
00:20:10 27 Suzy - R.U.N (None) (Playlist 4)
00:21:11 28 AOA Cream - I'm Jelly BABY (None) (Playlist 4)
00:21:59 29 LE SSERAFIM - Swan Song (None) (None)
00:22:47 30 Kep1er - Galileo (None) (None)
00:23:35 31 GFriend - Rough (None) (None)
00:24:15 32 NINE.i - Turn it Off (None) (None)
00:25:03 33 Everglow - Adios (None) (None)
00:25:58 34 Twice - I can't Stop me (None) (None)
00:26:54 35 Red Velvet - Birthday (None) (None)
00:27:36 36 Blackpink - How you like That (Dancebreak) (None)
00:28:25 37 Troublemaker - Troublemaker (None) (None)
00:29:12 38 BTS - Mic Drop (None) (None)
00:30:10 39 aespa - Thirsty (None) (None)
00:30:58 40 Taemin - The Rizzness (None) (None)
00:31:26 41 Jhope - Hope World (None) (None)
00:31:56 42 Taemin - Advice (None) (None)
00:32:43 43 CRAVITY - Adrenaline (None) (None)
00:33:32 44 GOT the Beat - Step Back (None) (None)
00:34:13 45 BigBang - Bang Bang Bang (None) (None)
00:34:55 46 IVE - I Am (None) (None)
00:35:26 47 Mamamoo - Aya (None) (None)
00:36:06 48 JYP - Groove Back (None) (None)
00:36:55 49 Monsta X - Hero (None) (None)
00:37:41 50 Oneus - No Diggity (Dancebreak) (None)
00:38:21 51 Kim Sejeong - Top or Cliff (None) (Playlist 4)
00:39:14 52 Dynamic Duo - Smoke (None) (None)
00:39:48 53 EXID - Ah Yeah (None) (None)
00:40:25 54 Red Velvet - Bad Boy (None) (Playlist 4)
00:41:18 55 Twice - What is Love?  (None) (None)
00:41:57 56 Stray Kids - Super Bowl (None) (None)
00:42:34 57 NCT U - Baggy Jeans (None) (None)"""

# %% [markdown]
# ### Output

# %% [markdown]
# #### Hashtags for YT Video

# %%
raw_list = raw.split("\n")

export_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_edit = "".join(e for e in artist if e.isalnum()).upper()
    export_list.append(artist_edit)

export_list.sort()
export_list = list(dict.fromkeys(export_list))

artist_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_list.append(artist)

title_list = []
for x in raw_list:
    title = x.split(" - ")[1].split(" (")[0]
    title_list.append(title)

print("#" + " #".join(export_list))
# Out:
# #2PM #4MINUTE #7LOVEMINUTES #AESPA #ALEXA #AOACREAM #APINK #ATEEZ #BABYMONSTER #BAEKHYUN #BI #BIGBANG #BILLLIE #BLACKPINK #BOYNEXTDOOR #BOYSTORY #BRAVEGIRLS #BTS #CHUNGHA #CRAVITY #DKB #DREAMCATCHER #DYNAMICDUO #ELAST #ENHYPEN #EVERGLOW #EVNNE #EXID #EXO #FROMIS9 #FX #GFRIEND #GHOST9 #GIDLE #GIRLSGENERATION #GIRLSPLANET999 #GOT7 #GOTTHEBEAT #HEARTSTEEL #HINAPIA #HWASA #INFINITE #ITZY #IVE #IZONE #JENNIE #JHOPE #JIMIN #JINI #JUN #JYP #KARD #KEP1ER #KIMSEJEONG #KISSOFLIFE #LEESUHYUN #LESSERAFIM #LOONA #MAMAMOO #MAMAOO #MOMOLAND #MONSTAX #NCT127 #NCTDREAM #NCTU #NCTWISH #NEWJEANS #NINEI #NIZIU #NMIXX #NOIR #ONEUS #ONLYONEOF #ORANGECARAMEL #P1HARMONY #PENTAGON #PRODUCE48 #PURPLEKISS #REDVELVET #SEVENTEEN #SIS #SOMI #SOOJIN #STARSEEDZ #STAYC #STRAYKIDS #SUNMI #SUZY #TAEMIN #TEN #THEBOYZ #THEWIND #TRIBE #TROUBLEMAKER #TWICE #TWS #VCHA #VERIVERY #VIVIZ #WAYV #WEEEKLY #WEKIMEKI #WOOAH #XDINARYHEROES #XG #YOUNGPOSSE #YUTOADACHI #ZEROBASEONE

# %% [markdown]
# #### Artist and Title

# %%
print("\n".join(artist_list))
print("\n\n\n\n\n\n")
print("\n".join(title_list))
# Out:
# Twice
# Jimin
# STAYC
# Yuto Adachi
# Stray Kids
# (G)I-DLE
# IVE
# LE SSERAFIM
# Got7
# (G)I-DLE
# f(x)
# NiziU
# 4Minute
# CRAVITY
# Kard
# Enhypen
# Red Velvet
# aespa
# Babymonster
# Dreamcatcher
# LE SSERAFIM
# Mamamoo
# Pentagon
# Ateez
# E'last
# Seventeen
# Itzy
# NMIXX
# Hwasa
# Taemin
# Twice
# 2PM
# (G)I-DLE
# Kep1er
# Blackpink
# TEN
# Exo
# NCT Wish
# Xdinary Heroes
# Alexa
# Brave Girls
# Stray Kids
# Billlie
# NCT 127
# Everglow
# Oneus
# aespa
# Iz*one
# 7 LOVE Minutes
# Itzy
# Chung Ha
# Enhypen
# Ghost9
# The Boyz
# VERIVERY
# Twice
# Weeekly
# (G)I-DLE
# Lee Suhyun
# Blackpink
# CRAVITY
# Produce 48
# Mamaoo
# Apink
# Itzy
# EXO
# Everglow
# TEN
# Stray Kids
# The Boyz
# Kep1er
# aespa
# NewJeans
# Enhypen
# OnlyOneOf
# VIVIZ
# P1harmony
# Girls Generation
# Kard
# BTS
# IZ*ONE
# Twice
# Enhypen
# LE SSERAFIM
# Stray Kids
# Itzy
# Somi
# Blackpink
# Babymonster
# Enhypen
# LE SSERAFIM
# JINI
# Red Velvet
# NMIXX
# ZEROBASEONE
# NMIXX
# (G)I-DLE
# Hinapia
# ...

# %% [markdown]
# ## Timestamp Creator for YT Video

# %% [markdown]
# ### Input

# %%
import math

startTime = "00:00:05"

raw = """
00:00:03 1 VCHA - Ready for the World (None) (None)
00:00:47 2 Stray Kids - LALALALA (Dancebreak) (None)
00:01:37 3 Young Posse - OTB (None) (None)
00:02:14 4 The Boyz - Roar (None) (None)
startTimeInSeconds += int(startTimeSplit[1]) * 60
startTimeInSeconds += int(startTimeSplit[2])

rawSplit = raw.split("\n")[1:-1]
for x in rawSplit:
    playlistTimeStampInSeconds = 0
    newTimeStampHour = 0
    newTimeStampMinute = 0

    # Remove unnecassary Suffix
    noSuffix = x.rsplit(" (", 2)[0]
    noSuffixSplit = noSuffix.split(" ", 2)

    playlistTimeStampSplit = noSuffixSplit[0].split(":")
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[0]) * 60 * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[1]) * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[2])

    newTimeStampInSeconds = startTimeInSeconds + playlistTimeStampInSeconds

    newTimeStampHour =  math.floor(newTimeStampInSeconds / 3600)
    newTimeStampInSeconds = newTimeStampInSeconds % 3600
    newTimeStampHourString = str(newTimeStampHour).zfill(2)

    newTimeStampMinute =  math.floor(newTimeStampInSeconds / 60)
    newTimeStampInSeconds = newTimeStampInSeconds % 60
    newTimeStampMinuteString = str(newTimeStampMinute).zfill(2)

    newTimeStampSecondString =str(newTimeStampInSeconds).zfill(2)

    newTimeStampString = ":".join([newTimeStampHourString, newTimeStampMinuteString, newTimeStampSecondString])

    print(newTimeStampString + " " + noSuffixSplit[2])
# Out:
# 00:00:08 VCHA - Ready for the World
# 00:00:52 Stray Kids - LALALALA
# 00:01:42 Young Posse - OTB
# 00:02:19 The Boyz - Roar
# 00:03:00 IZ*ONE - Fiesta
# 00:04:01 Ateez - Crazy Form
# 00:04:50 Exo - The Eve
# 00:05:37 NMIXX - Roller Coaster
# 00:06:14 LE SSERAFIM - Antifragile
# 00:07:04 Sunmi - Heroine
# 00:08:00 Woo!ah!  - Rollercoaster
# 00:08:48 Enhypen  - Mixed Up
# 00:09:27 TRI.BE - Would you Run
# 00:10:25 Itzy - Dalla Dalla
# 00:11:10 P1harmony - Pyramid
# 00:12:13 Dreamcatcher - Boca
# 00:13:04 Boynextdoor - One and Only
# 00:13:42 Pentagon - Dr. Bebe
# 00:14:39 STARSEED'Z - ICONIC
# 00:15:17 Enhypen - Fever
# 00:16:03 Itzy - UNTOUCHABLE
# 00:17:01 S.I.S - Always be your Girl
# 00:17:44 Ateez - Crazy Form
# 00:18:15 WAYV - Turn Back Time
# 00:18:56 B.I - BTBT
# 00:19:27 Hwasa - I'm a B
# 00:20:15 Suzy - R.U.N
# 00:21:16 AOA Cream - I'm Jelly BABY
# 00:22:04 LE SSERAFIM - Swan Song
# 00:22:52 Kep1er - Galileo
# 00:23:40 GFriend - Rough
# 00:24:20 NINE.i - Turn it Off
# ...

# %%
import json
import yt_dlp

URL = 'https://www.youtube.com/watch?v=BaW_jenozKc'

# ℹ️ See help(yt_dlp.YoutubeDL) for a list of available options and public functions
ydl_opts = {}
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(URL, download=False)

    # ℹ️ ydl.sanitize_info makes the info json-serializable
    print(info['title'])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BaW_jenozKc
# [youtube] BaW_jenozKc: Downloading webpage
# [youtube] BaW_jenozKc: Downloading ios player API JSON
# [youtube] BaW_jenozKc: Downloading android player API JSON
# [youtube] BaW_jenozKc: Downloading m3u8 information
# youtube-dl test video "'/\ä↭𝕐
