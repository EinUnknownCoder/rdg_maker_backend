# %% [markdown]
# # Minitools

# %% [markdown]
# ## Hashtrag Creator for Instagram-/YT-Shorts-/TikTok-Posts

# %% [markdown]
# ### Input

# %%
songs = """JIHYO - Closer
tripleS AAA - Generation
ENHYPEN - Criminal Love
EVNNE - TROUBLE
TXT - Chasing That Feeling
NCT 127 - Fact Check
aespa - Drama
iKON - KILLING ME
P1Harmony - Butterfly"""

# %% [markdown]
# ### Output

# %%
songs_list = songs.split("\n")
song_split = []
for x in range(len(songs_list)):
    hashtags = []
    song_split.append([])
    for y in range(2):
        song_split[x].append(''.join(e for e in songs_list[x].split(" - ")[y] if e.isalnum()).lower())
    hashtags.append(f"#{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][0]}{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}dancecover")
    hashtags.append(f"#{song_split[x][0]}edit")
    print(" ".join(hashtags))
# Out:
# #jihyo #closer #closerjihyo #jihyocloser #closerdancecover #jihyoedit
# #triplesaaa #generation #generationtriplesaaa #triplesaaageneration #generationdancecover #triplesaaaedit
# #enhypen #criminallove #criminalloveenhypen #enhypencriminallove #criminallovedancecover #enhypenedit
# #evnne #trouble #troubleevnne #evnnetrouble #troubledancecover #evnneedit
# #txt #chasingthatfeeling #chasingthatfeelingtxt #txtchasingthatfeeling #chasingthatfeelingdancecover #txtedit
# #nct127 #factcheck #factchecknct127 #nct127factcheck #factcheckdancecover #nct127edit
# #aespa #drama #dramaaespa #aespadrama #dramadancecover #aespaedit
# #ikon #killingme #killingmeikon #ikonkillingme #killingmedancecover #ikonedit
# #p1harmony #butterfly #butterflyp1harmony #p1harmonybutterfly #butterflydancecover #p1harmonyedit

# %% [markdown]
# ## Hashtag Creator for YT Video + Artist/Title Lister

# %% [markdown]
# ### Input (YT Timestamps)

# %%
raw = """00:00:03 1 loona - hula hoop (Chorus 1) (None)
00:01:12 2 Seventeen - Cheers (Chorus 1) (None)
00:01:52 3 SF9 - Summer breeze (Chorus 1) (None)
00:02:41 4 ENHYPEN - Hey tayo (Chorus 1) (None)
00:03:14 5 Purple kiss - Nerdy (Chorus 1) (None)
00:04:03 6 Iz*one - Secret story of the swan (Dancebreak) (None)
00:05:09 7 Everglow - Neverglow (Chorus 1) (APF: Neverglow Dun Dun Playlist 2)
00:05:41 8 New Jeans - Supershy (Chorus 1) (APF: Toad Cover Playlist 2)
00:06:25 9 Stray Kids - Megaverse (Dancebreak) (None)
00:07:32 10 2PM - HIGHER (Chorus 1) (None)
00:08:20 11 Dreamcatcher - Chase me (Pre-Chorus 1) (None)
00:09:03 12 WJSN - La LA Love (Pre-Chorus 1) (None)
00:09:58 13 NCT U - Baggy Jeans (Chorus 1) (None)
00:21:57 27 Gidle - Queencard (Chorus 1) (APF: Slowed + Reverbed Playlist 4)
00:22:52 28 Kim Sejeong - Top or Cliff (Pre-Chorus 1) (None)
00:23:54 29 HIGHLIGHT - Body (Chorus 1) (Chi)
00:24:39 30 Weki Meki - Dazzle Dazzle (Chorus 1) (None)
00:25:35 31 Jimin - Filter (Chorus 2, Dancebreak) (None)
00:26:46 32 Hyoyeon - Wannabe (Chorus 1) (None)
00:27:28 33 Nmixx - Run for roses (Chorus 1) (None)
00:28:03 34 WJSN - 흥칫뿡 (Chorus 1) (APF: Girls Planet Hmph! Playlist 4)
00:28:49 35 Wonder Girls - Tell Me (Chorus 1) (APF: JYP Playlist 4)
00:29:50 36 Pentagon - Dr.bebe (Chorus 2) (None)
00:30:34 37 Stray kids - I am you (Chorus 3) (None)
00:31:17 38 Kai - Rover (Chorus 1) (None)"""

# %% [markdown]
# ### Output

# %% [markdown]
# #### Hashtags for YT Video

# %%
raw_list = raw.split("\n")

export_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_edit = "".join(e for e in artist if e.isalnum()).upper()
    export_list.append(artist_edit)

export_list.sort()
export_list = list(dict.fromkeys(export_list))

artist_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_list.append(artist)

title_list = []
for x in raw_list:
    title = x.split(" - ")[1].split(" (")[0]
    title_list.append(title)

print("#" + " #".join(export_list))
# Out:
# #2PM #3YE #ACE #AESPA #ATEEZ #BI #BLACKPINK #BOYSTORY #BTS #CHUNGHA #CLASSY #CLC #DPR #DREAMCATCHER #ENHA #ENHYPEN #EVERGLOW #EVNNE #FROMIS9 #GFRIEND #GIDLE #GIRLGENERATION #GIRLSGENERATION #GUGUDAN #HIGHLIGHT #HYOLYN #HYOYEON #ITZY #IVE #IZONE #JIMIN #JUN #JUNGKOOK #JUSTB #KAI #KEP1ER #KEY #KIMSEJEONG #KIMWOOSEOK #KINGDOM #KINO #LAPILLUS #LESSERAFIM #LISA #LOONA #MAMAMOO #MAVE #MCND #MONSTAX #MOONBYUL #NAYEON #NCT127 #NCTDOJAEJUNG #NCTU #NCTXAESPA #NEWJEANS #NMIXX #P1HARMONY #PENTAGON #PIXY #PURPLEKISS #REDVELVET #RIIZE #SEVENTEEN #SF9 #STAYC #STRAYKIDS #TAEMIN #TAEYONG #TEMPEST #TEN #TNX #TREASURE #TRIBE #TWICE #TWS #TXT #UNIQ #VIVIZ #WAYV #WEKIMEKI #WJSN #WONDERGIRLS #XG #YENA #YUTO #ZEROBASEONE

# %% [markdown]
# #### Artist and Title

# %%
print("\n".join(artist_list))
print("\n\n\n\n\n\n")
print("\n".join(title_list))
# Out:
# Twice
# Jimin
# STAYC
# Yuto Adachi
# Stray Kids
# (G)I-DLE
# IVE
# LE SSERAFIM
# Got7
# (G)I-DLE
# f(x)
# NiziU
# 4Minute
# CRAVITY
# Kard
# Enhypen
# Red Velvet
# aespa
# Babymonster
# Dreamcatcher
# LE SSERAFIM
# Mamamoo
# Pentagon
# Ateez
# E'last
# Seventeen
# Itzy
# NMIXX
# Hwasa
# Taemin
# Twice
# 2PM
# (G)I-DLE
# Kep1er
# Blackpink
# TEN
# Exo
# NCT Wish
# Xdinary Heroes
# Alexa
# Brave Girls
# Stray Kids
# Billlie
# NCT 127
# Everglow
# Oneus
# aespa
# Iz*one
# 7 LOVE Minutes
# Itzy
# Chung Ha
# Enhypen
# Ghost9
# The Boyz
# VERIVERY
# Twice
# Weeekly
# (G)I-DLE
# Lee Suhyun
# Blackpink
# CRAVITY
# Produce 48
# Mamaoo
# Apink
# Itzy
# EXO
# Everglow
# TEN
# Stray Kids
# The Boyz
# Kep1er
# aespa
# NewJeans
# Enhypen
# OnlyOneOf
# VIVIZ
# P1harmony
# Girls Generation
# Kard
# BTS
# IZ*ONE
# Twice
# Enhypen
# LE SSERAFIM
# Stray Kids
# Itzy
# Somi
# Blackpink
# Babymonster
# Enhypen
# LE SSERAFIM
# JINI
# Red Velvet
# NMIXX
# ZEROBASEONE
# NMIXX
# (G)I-DLE
# Hinapia
# ...

# %% [markdown]
# ## Timestamp Creator for YT Video

# %% [markdown]
# ### Input

# %%
import math

startTime = "01:30:18"

raw = """
00:15:10 19 iz*one - fiesta (Pre-Chorus 1) (None)
00:16:21 20 Enha - GIVEN-TAKEN (Chorus 3) (None)
00:17:13 21 Ateez - Guerrilla (Chorus 1) (None)
00:18:03 22 Seventeen - God of Music (Chorus 1) (None)
00:18:50 23 TNX - Move (Chorus 1) (None)
00:19:28 24 txt - Chasing that feeling (Pre-Chorus 2, Dancebreak) (None)
00:20:23 25 Lapillus - Hit Ya! (Chorus 1) (None)
00:21:10 26 Ace - Favorite Boys (Chorus 1) (Goblin)
00:21:57 27 Gidle - Queencard (Chorus 1) (APF: Slowed + Reverbed Playlist 4)
00:22:52 28 Kim Sejeong - Top or Cliff (Pre-Chorus 1) (None)
00:23:54 29 HIGHLIGHT - Body (Chorus 1) (Chi)
00:24:39 30 Weki Meki - Dazzle Dazzle (Chorus 1) (None)
00:25:35 31 Jimin - Filter (Chorus 2, Dancebreak) (None)
00:26:46 32 Hyoyeon - Wannabe (Chorus 1) (None)
00:27:28 33 Nmixx - Run for roses (Chorus 1) (None)
00:28:03 34 WJSN - 흥칫뿡 (Chorus 1) (APF: Girls Planet Hmph! Playlist 4)
00:28:49 35 Wonder Girls - Tell Me (Chorus 1) (APF: JYP Playlist 4)
00:29:50 36 Pentagon - Dr.bebe (Chorus 2) (None)
00:30:34 37 Stray kids - I am you (Chorus 3) (None)
00:31:17 38 Kai - Rover (Chorus 1) (None)
"""

# %% [markdown]
# ### Output

# %%
startTimeSplit = startTime.split(":")
startTimeInSeconds = 0
startTimeInSeconds += int(startTimeSplit[0]) * 60 * 60
startTimeInSeconds += int(startTimeSplit[1]) * 60
startTimeInSeconds += int(startTimeSplit[2])

rawSplit = raw.split("\n")[1:-1]
for x in rawSplit:
    playlistTimeStampInSeconds = 0
    newTimeStampHour = 0
    newTimeStampMinute = 0

    # Remove unnecassary Suffix
    noSuffix = x.rsplit(" (", 2)[0]
    noSuffixSplit = noSuffix.split(" ", 2)

    playlistTimeStampSplit = noSuffixSplit[0].split(":")
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[0]) * 60 * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[1]) * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[2])

    newTimeStampInSeconds = startTimeInSeconds + playlistTimeStampInSeconds

    newTimeStampHour =  math.floor(newTimeStampInSeconds / 3600)
    newTimeStampInSeconds = newTimeStampInSeconds % 3600
    newTimeStampHourString = str(newTimeStampHour).zfill(2)

    newTimeStampMinute =  math.floor(newTimeStampInSeconds / 60)
    newTimeStampInSeconds = newTimeStampInSeconds % 60
    newTimeStampMinuteString = str(newTimeStampMinute).zfill(2)

    newTimeStampSecondString =str(newTimeStampInSeconds).zfill(2)

    newTimeStampString = ":".join([newTimeStampHourString, newTimeStampMinuteString, newTimeStampSecondString])

    print(newTimeStampString + " " + noSuffixSplit[2])
# Out:
# 01:45:28 iz*one - fiesta
# 01:46:39 Enha - GIVEN-TAKEN
# 01:47:31 Ateez - Guerrilla
# 01:48:21 Seventeen - God of Music
# 01:49:08 TNX - Move
# 01:49:46 txt - Chasing that feeling
# 01:50:41 Lapillus - Hit Ya!
# 01:51:28 Ace - Favorite Boys
# 01:52:15 Gidle - Queencard
# 01:53:10 Kim Sejeong - Top or Cliff
# 01:54:12 HIGHLIGHT - Body
# 01:54:57 Weki Meki - Dazzle Dazzle
# 01:55:53 Jimin - Filter
# 01:57:04 Hyoyeon - Wannabe
# 01:57:46 Nmixx - Run for roses
# 01:58:21 WJSN - 흥칫뿡
# 01:59:07 Wonder Girls - Tell Me
# 02:00:08 Pentagon - Dr.bebe
# 02:00:52 Stray kids - I am you
# 02:01:35 Kai - Rover

# %% [markdown]
# # Playground

# %%
import json
import yt_dlp

URL = 'https://www.youtube.com/watch?v=BaW_jenozKc'

# ℹ️ See help(yt_dlp.YoutubeDL) for a list of available options and public functions
ydl_opts = {}
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(URL, download=False)

    # ℹ️ ydl.sanitize_info makes the info json-serializable
    print(info['title'])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BaW_jenozKc
# [youtube] BaW_jenozKc: Downloading webpage
# [youtube] BaW_jenozKc: Downloading ios player API JSON
# [youtube] BaW_jenozKc: Downloading android player API JSON
# WARNING: [youtube] Skipping player responses from android clients (got player responses for video "aQvGIIdgFDM" instead of "BaW_jenozKc")
# [youtube] BaW_jenozKc: Downloading m3u8 information
# youtube-dl test video "'/\ä↭𝕐
