# %% [markdown]
# # Minitools

# %% [markdown]
# ## Hashtrag Creator for Instagram-/YT-Shorts-/TikTok-Posts

# %% [markdown]
# ### Input

# %%
songs = """JIHYO - Closer
tripleS AAA - Generation
ENHYPEN - Criminal Love
EVNNE - TROUBLE
TXT - Chasing That Feeling
NCT 127 - Fact Check
aespa - Drama
iKON - KILLING ME
P1Harmony - Butterfly"""
# Out:
# Running cells with '.venv (Python 3.11.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Documents/Code/rdg_playlist_maker/20250425/rdg_maker_backend/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ### Output

# %%
songs_list = songs.split("\n")
song_split = []
for x in range(len(songs_list)):
    hashtags = []
    song_split.append([])
    for y in range(2):
        song_split[x].append(''.join(e for e in songs_list[x].split(" - ")[y] if e.isalnum()).lower())
    hashtags.append(f"#{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][0]}{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}dancecover")
    hashtags.append(f"#{song_split[x][0]}edit")
    print(" ".join(hashtags))

# %% [markdown]
# ## Hashtag Creator for YT Video + Artist/Title Lister

# %% [markdown]
# ### Input (YT Timestamps)

# %%
raw = """00:00:03 1 IRENE & SEULGI - NAUGHTY (Chorus 1) (th4ivv)
00:00:56 2 Xiumin - WHEE! (Chorus 1) (@_adri_2210)
00:01:45 3 izna - Timebomb (Chorus 2, Dancebreak) (dustinthetea)
00:03:02 4 Bebe Rexha - Break My Heart Myself (Chorus 2, Dancebreak, Dance Studio) (anastasia_.29)
00:04:31 5 BTS - Baepsae (Intro) (57idemircan@gmail.com)
00:05:16 6 SEVENTEEN - ASH (Verse, Dance Studio) (stella.adj)
00:06:07 7 Enhypen - bleeding darkness (Dancebreak, Dance Studio) (Wonluv4me)
00:07:05 8 EXO - The Eve (Chorus 1) (jennova143)
00:07:50 9 Kai - Adult Swim (Dancebreak) (0__liliana)
00:08:58 10 Jason Derulo - Tip toe (Dancebreak, Dance Studio, 18 Plus) (corinab683@gmail.com)
00:10:21 11 PIXY - Flip a Coin (Chorus 1) (@doooorado)
00:11:07 12 Kendrick Lamar - Humble (Dance Studio) (just.tiff08)
00:12:17 13 Doja Cat - Boss bitch (Chorus 1, Dance Studio) (amee_kii, Playlist 1)
00:13:14 14 Ciara - Freak me (18 Plus) (andrea_lxj.2919)
00:14:35 15 Ludacris - What’s Your Fantasy (Dance Studio) (anastasia_.29)
00:15:36 16 RIIZE - Hug (Chorus 1) (02.d3em)
00:16:45 17 Ateez - Silver light (Chorus 1, Dance Studio) (Jara_roam)
00:17:51 18 BLACKPINK - Whistle (Dancebreak) (kurakisse.s)
00:18:48 19 Ariana Grande  - Into you (Dance Studio) (_Glitterdoll, Playlist 1)
00:19:51 20 Solar - Colors (Chorus 1) (m.vescio@freenet.de)
00:20:57 21 AleXa - Bomb (Chorus 1) (anni04nagel@gmail.com)
00:21:57 22 Stray Kids - I like it (Chorus 1) (_li0nyuqi)
00:22:40 23 Tri.Be - Lobo (Chorus 2, Dancebreak) (@Kevin_istalleinezuhause)
00:24:14 24 Kiss of Life - Midas Touch (Dancebreak) (leyla_38551)
00:25:07 25 NCT U - BOSS (Chorus 1) (@ncity_25dream)
00:25:55 26 Rainbow - A (Chorus 1) (annalena.ch2002@gmail.com)
00:27:04 27 Tobii - Bad Girls Like you (Chorus 1, Dance Studio, 18 Plus) (mo_n_dy, Eva_)
00:27:54 28 Tate McRae - Sports car (Dance Studio, 18 Plus) (@linavyeh)
00:28:52 29 HOSHI - SPIDER (Chorus 1) (abc.tuxel@gmail.com)"""

# %% [markdown]
# ### Output

# %% [markdown]
# #### Hashtags for YT Video

# %%
raw_list = raw.split("\n")

export_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_edit = "".join(e for e in artist if e.isalnum()).upper()
    export_list.append(artist_edit)

export_list.sort()
export_list = list(dict.fromkeys(export_list))

artist_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_list.append(artist)

title_list = []
for x in raw_list:
    title = x.split(" - ")[1].split(" (")[0]
    title_list.append(title)

print("#" + " #".join(export_list))
# Out:
# #2NE1 #8TURN #ACE #AESPA #ALEXA #AMPERSONE #ARIANAGRANDE #ATEEZ #AVAMAX #BADVILLAIN #BEBEREXHA #BIGOCEAN #BILLIEEILISH #BLACKPINK #BRUNOMARS #BSS #BTS #CHARLIXCX #CHERRYBULLET #CHUNGHA #CIARA #CL #CLASSY #COCOJONES #DESTINYSCHILD #DOJACAT #ENHYPEN #EXO #FX #GOT7 #GRANT #HOSHI #HOSHIXWOOZI #ILAND #INI #IRENESEULGI #ITZY #IU #IVE #IZNA #JAMIEFOXX #JASONDERULO #JBALVIN #JENNIE #JHOPE #JO1 #KAI #KANYEWEST #KARD #KENDRICKLAMAR #KEP1ER #KIIIKIII #KISSOFLIFE #LADYGAGA #LAHPAT #LESSERAFIM #LUDACRIS #LUN8 #MARIANHILL #NCTDREAM #NCTU #NCTWISH #NMIXX #PIXY #POSTMALONE #PURPLEKISS #RAINBOW #REDVELVET #RIHANNAFEATBRITNEYSPEARSE #RIIZE #RUPAUL #SEULGI #SEVENTEEN #SOLAR #STAYC #STEFFLONDON #STRAYKIDS #STRAYKIDSHANFELIX #TARA #TATEMCRAE #TEN #THEBOYZ #THEWEEKND #TOBII #TOMORROWXTOGETHER #TRIBE #TWICE #WENA #XIUMIN #YEJI #YOUHA

# %% [markdown]
# #### Artist and Title

# %%
print("\n".join(artist_list))
print("\n\n\n\n\n\n")
print("\n".join(title_list))
# Out:
# Twice
# Jimin
# STAYC
# Yuto Adachi
# Stray Kids
# (G)I-DLE
# IVE
# LE SSERAFIM
# Got7
# (G)I-DLE
# f(x)
# NiziU
# 4Minute
# CRAVITY
# Kard
# Enhypen
# Red Velvet
# aespa
# Babymonster
# Dreamcatcher
# LE SSERAFIM
# Mamamoo
# Pentagon
# Ateez
# E'last
# Seventeen
# Itzy
# NMIXX
# Hwasa
# Taemin
# Twice
# 2PM
# (G)I-DLE
# Kep1er
# Blackpink
# TEN
# Exo
# NCT Wish
# Xdinary Heroes
# Alexa
# Brave Girls
# Stray Kids
# Billlie
# NCT 127
# Everglow
# Oneus
# aespa
# Iz*one
# 7 LOVE Minutes
# Itzy
# Chung Ha
# Enhypen
# Ghost9
# The Boyz
# VERIVERY
# Twice
# Weeekly
# (G)I-DLE
# Lee Suhyun
# Blackpink
# CRAVITY
# Produce 48
# Mamaoo
# Apink
# Itzy
# EXO
# Everglow
# TEN
# Stray Kids
# The Boyz
# Kep1er
# aespa
# NewJeans
# Enhypen
# OnlyOneOf
# VIVIZ
# P1harmony
# Girls Generation
# Kard
# BTS
# IZ*ONE
# Twice
# Enhypen
# LE SSERAFIM
# Stray Kids
# Itzy
# Somi
# Blackpink
# Babymonster
# Enhypen
# LE SSERAFIM
# JINI
# Red Velvet
# NMIXX
# ZEROBASEONE
# NMIXX
# (G)I-DLE
# Hinapia
# ...

# %% [markdown]
# ## Timestamp Creator for YT Video

# %% [markdown]
# ### Input

# %%
import math

startTime = "00:00:06"

raw = """
00:00:03 1 IRENE & SEULGI - NAUGHTY (Chorus 1) (th4ivv)
00:00:56 2 Xiumin - WHEE! (Chorus 1) (@_adri_2210)
00:01:45 3 izna - Timebomb (Chorus 2, Dancebreak) (dustinthetea)
00:03:02 4 Bebe Rexha - Break My Heart Myself (Chorus 2, Dancebreak, Dance Studio) (anastasia_.29)
00:04:31 5 BTS - Baepsae (Intro) (57idemircan@gmail.com)
00:05:16 6 SEVENTEEN - ASH (Verse, Dance Studio) (stella.adj)
00:06:07 7 Enhypen - bleeding darkness (Dancebreak, Dance Studio) (Wonluv4me)
00:07:05 8 EXO - The Eve (Chorus 1) (jennova143)
00:07:50 9 Kai - Adult Swim (Dancebreak) (0__liliana)
00:08:58 10 Jason Derulo - Tip toe (Dancebreak, Dance Studio, 18 Plus) (corinab683@gmail.com)
00:10:21 11 PIXY - Flip a Coin (Chorus 1) (@doooorado)
00:11:07 12 Kendrick Lamar - Humble (Dance Studio) (just.tiff08)
00:12:17 13 Doja Cat - Boss bitch (Chorus 1, Dance Studio) (amee_kii, Playlist 1)
00:13:14 14 Ciara - Freak me (18 Plus) (andrea_lxj.2919)
00:14:35 15 Ludacris - What’s Your Fantasy (Dance Studio) (anastasia_.29)
00:15:36 16 RIIZE - Hug (Chorus 1) (02.d3em)
00:16:45 17 Ateez - Silver light (Chorus 1, Dance Studio) (Jara_roam)
00:17:51 18 BLACKPINK - Whistle (Dancebreak) (kurakisse.s)
00:18:48 19 Ariana Grande  - Into you (Dance Studio) (_Glitterdoll, Playlist 1)
00:19:51 20 Solar - Colors (Chorus 1) (m.vescio@freenet.de)
00:20:57 21 AleXa - Bomb (Chorus 1) (anni04nagel@gmail.com)
00:21:57 22 Stray Kids - I like it (Chorus 1) (_li0nyuqi)
00:22:40 23 Tri.Be - Lobo (Chorus 2, Dancebreak) (@Kevin_istalleinezuhause)
00:24:14 24 Kiss of Life - Midas Touch (Dancebreak) (leyla_38551)
00:25:07 25 NCT U - BOSS (Chorus 1) (@ncity_25dream)
00:25:55 26 Rainbow - A (Chorus 1) (annalena.ch2002@gmail.com)
00:27:04 27 Tobii - Bad Girls Like you (Chorus 1, Dance Studio, 18 Plus) (mo_n_dy, Eva_)
00:27:54 28 Tate McRae - Sports car (Dance Studio, 18 Plus) (@linavyeh)
00:28:52 29 HOSHI - SPIDER (Chorus 1) (abc.tuxel@gmail.com)
"""

# %% [markdown]
# ### Output

# %%
startTimeSplit = startTime.split(":")
startTimeInSeconds = 0
startTimeInSeconds += int(startTimeSplit[0]) * 60 * 60
startTimeInSeconds += int(startTimeSplit[1]) * 60
startTimeInSeconds += int(startTimeSplit[2])

rawSplit = raw.split("\n")[1:-1]
for x in rawSplit:
    playlistTimeStampInSeconds = 0
    newTimeStampHour = 0
    newTimeStampMinute = 0

    # Remove unnecassary Suffix
    noSuffix = x.rsplit(" (", 2)[0]
    noSuffixSplit = noSuffix.split(" ", 2)

    playlistTimeStampSplit = noSuffixSplit[0].split(":")
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[0]) * 60 * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[1]) * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[2])

    newTimeStampInSeconds = startTimeInSeconds + playlistTimeStampInSeconds

    newTimeStampHour =  math.floor(newTimeStampInSeconds / 3600)
    newTimeStampInSeconds = newTimeStampInSeconds % 3600
    newTimeStampHourString = str(newTimeStampHour).zfill(2)

    newTimeStampMinute =  math.floor(newTimeStampInSeconds / 60)
    newTimeStampInSeconds = newTimeStampInSeconds % 60
    newTimeStampMinuteString = str(newTimeStampMinute).zfill(2)

    newTimeStampSecondString =str(newTimeStampInSeconds).zfill(2)

    newTimeStampString = ":".join([newTimeStampHourString, newTimeStampMinuteString, newTimeStampSecondString])

    print(newTimeStampString + " " + noSuffixSplit[2])
# Out:
# 00:00:09 IRENE & SEULGI - NAUGHTY
# 00:01:02 Xiumin - WHEE!
# 00:01:51 izna - Timebomb
# 00:03:08 Bebe Rexha - Break My Heart Myself
# 00:04:37 BTS - Baepsae
# 00:05:22 SEVENTEEN - ASH
# 00:06:13 Enhypen - bleeding darkness
# 00:07:11 EXO - The Eve
# 00:07:56 Kai - Adult Swim
# 00:09:04 Jason Derulo - Tip toe
# 00:10:27 PIXY - Flip a Coin
# 00:11:13 Kendrick Lamar - Humble
# 00:12:23 Doja Cat - Boss bitch
# 00:13:20 Ciara - Freak me
# 00:14:41 Ludacris - What’s Your Fantasy
# 00:15:42 RIIZE - Hug
# 00:16:51 Ateez - Silver light
# 00:17:57 BLACKPINK - Whistle
# 00:18:54 Ariana Grande  - Into you
# 00:19:57 Solar - Colors
# 00:21:03 AleXa - Bomb
# 00:22:03 Stray Kids - I like it
# 00:22:46 Tri.Be - Lobo
# 00:24:20 Kiss of Life - Midas Touch
count = 0
timestamp_old = rawSplit[0].split(" ")[0]
for x in range(len(rawSplit)-1):
    caption_text += f"{x+1}\n"

    timestamp_next = rawSplit[x+1].split(" ")[0]
    caption_text += f"{timestamp_old},000 --> {timestamp_next},000\n"
    timestamp_old = timestamp_next

    # Remove unnecassary Suffix
    noSuffixSplit = rawSplit[x].split(" ", 1)
    caption_text += f"{noSuffixSplit[1]}\n\n".upper()
    
print(caption_text)
# Out:
# 1
# 00:00:00,000 --> 00:00:09,000
# RDG Start
#
# 1
# 00:00:09,000 --> 00:01:02,000
# IRENE & SEULGI - NAUGHTY
#
# 2
# 00:01:02,000 --> 00:01:51,000
# XIUMIN - WHEE!
#
# 3
# 00:01:51,000 --> 00:03:08,000
# IZNA - TIMEBOMB
#
# 4
# 00:03:08,000 --> 00:04:37,000
# BEBE REXHA - BREAK MY HEART MYSELF
#
# 5
# 00:04:37,000 --> 00:05:22,000
# BTS - BAEPSAE
#
# 6
# 00:05:22,000 --> 00:06:13,000
# SEVENTEEN - ASH
#
# 7
# 00:06:13,000 --> 00:07:11,000
# ENHYPEN - BLEEDING DARKNESS
#
# 8
# 00:07:11,000 --> 00:07:56,000
# EXO - THE EVE
#
# 9
# 00:07:56,000 --> 00:09:04,000
# KAI - ADULT SWIM
#
# 10
# 00:09:04,000 --> 00:10:27,000
# JASON DERULO - TIP TOE
#
# 11
# 00:10:27,000 --> 00:11:13,000
# PIXY - FLIP A COIN
#
# 12
# 00:11:13,000 --> 00:12:23,000
# KENDRICK LAMAR - HUMBLE
#
# 13
# 00:12:23,000 --> 00:13:20,000
# DOJA CAT - BOSS BITCH
#
# 14
# 00:13:20,000 --> 00:14:41,000
# CIARA - FREAK ME
#
# 15
# 00:14:41,000 --> 00:15:42,000
# LUDACRIS - WHAT’S YOUR FANTASY
#
# 16
# ...

# %% [markdown]
# # Playground

# %%
import json
import yt_dlp

URL = 'https://www.youtube.com/watch?v=BaW_jenozKc'

# ℹ️ See help(yt_dlp.YoutubeDL) for a list of available options and public functions
ydl_opts = {}
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(URL, download=False)

    # ℹ️ ydl.sanitize_info makes the info json-serializable
    print(info['title'])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BaW_jenozKc
# [youtube] BaW_jenozKc: Downloading webpage
# [youtube] BaW_jenozKc: Downloading ios player API JSON
# [youtube] BaW_jenozKc: Downloading android player API JSON
# ERROR: [youtube] BaW_jenozKc: Video unavailable. This video has been removed by the uploader
# ---------------------------------------------------------------------------
# ExtractorError                            Traceback (most recent call last)
# File d:\Documents\Code\rdg_maker_backend\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1594, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1593 try:
# -> 1594     return func(self, *args, **kwargs)
#    1595 except (DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#
# File d:\Documents\Code\rdg_maker_backend\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1729, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1728 try:
# ...

# %%
raw = """00:00:03 1 tripleS - Girls never die (Chorus 2) (Mel)
00:00:36 2 TXT - Chasing that Feeling (Chorus) (Basic)
00:01:11 3 Iz*One - Panorama (Chorus) (Alissa)
00:01:57 4 Ill'it - Magnetic (Chorus) (Basic)
00:02:37 5 StrayKids - God's Menu (Pre-Chorus, Chorus) (Basic)
00:03:21 6 Han Seungwoo - Sacrifice (Chorus 2) (Ace)
00:04:01 7 EXO - Ooh La La La (Chorus) (Adriana)
00:04:34 8 Kiss of Life - Midas Touch (Pre-Chorus, Chorus) (Milla)
00:05:06 9 &Team - Samidare (Chorus) (Salina)
00:05:58 10 Ateez - Horizon (Chorus) (Yuki)
00:06:26 11 Billie - Gingamingayo (Chorus) (Yuki)
00:07:17 12 (G)-idle - Wife (Pre-Chorus, Chorus 2) (Lilly)
00:08:00 13 NCT U - Baby don't stop (Chorus) (Mel)
00:08:34 14 Loossemble - ‘Girls’ Night’ (Dancebreak) (Salina)
00:09:28 15 Twice - MORE & MORE (Dancebreak) (Ines)
00:10:15 16 Aespa - Drama (Chorus) (Basic)
00:10:56 17 Enhypen - Bite me (Dancebreak) (Ivan)
00:11:48 18 Bts - Fire (Chorus) (Thony)
00:12:32 19 Everglow - Bon Bon Chocolat (Chorus) (Basic)
00:13:19 20 KARD - Icky (Chorus) (Basic)
00:13:55 21 JungKook - Standing Next To You (Dancebreak) (Basic)
00:14:42 22 IVE - I Am (Chorus) (Basic)
00:15:08 23 Xikers - Tricky House (Dancebreak) (Basic)
00:15:38 24 Taemin - Advice (Chorus) (Jake)
00:16:27 25 Enhypen - mixed up (Pre-Chorus, Chorus) (Marry)
00:17:13 26 Seventeen - Left & Right (Chorus) (Ace)
00:17:57 27 PSY - Gangnam Style (Chorus) (Basic)
00:18:35 28 Boynextdoor - Earth, Wind & Fire (Chorus) (Milla)
00:19:07 29 VCHA - Only One (Pre-Chorus, Chorus) (Alessa)
00:19:59 30 Itzy - Loco (Chorus) (Basic)
00:20:36 31 Chung Ha  - Snapping (Chorus) (Basic)
00:21:20 32 Soñar (Breaker) - NMIXX (Chorus 2, Dancebreak) (Lera)
00:22:33 33 WayV - Regular (Chorus) (Ascela)
00:23:12 34 NCT 127 - Kick it (Intro) (Basic)
00:23:49 35 OMEGAX - JUNK FOOD (Pre-Chorus, Chorus) (Marry)
00:24:23 36 Babymonster - Sheesh (Pre-Chorus, Chorus) (Hanna)"""

# %%
arr = raw.split("\n")
sec = 0
for x in arr:
    temp = x.split(" ")[0].split(":")
    sec = int(temp[2]) + (int(temp[1]) * 60) + (int(temp[0]) * 360)
    print(sec)
# Out:
# 3
# 36
# 71
# 117
# 157
# 201
# 241
# 274
# 306
# 358
# 386
# 437
# 480
# 514
# 568
# 615
# 656
# 708
# 752
# 799
# 835
# 882
# 908
# 938
# 987
# 1033
# 1077
# 1115
# 1147
# 1199
# 1236
# 1280
# 1353
# 1392
# 1429
# 1463
