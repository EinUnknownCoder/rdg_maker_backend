# %% [markdown]
# # Minitools

# %% [markdown]
# ## Hashtrag Creator for Instagram-/YT-Shorts-/TikTok-Posts

# %% [markdown]
# ### Input

# %%
songs = """JIHYO - Closer
tripleS AAA - Generation
ENHYPEN - Criminal Love
EVNNE - TROUBLE
TXT - Chasing That Feeling
NCT 127 - Fact Check
aespa - Drama
iKON - KILLING ME
P1Harmony - Butterfly"""

# %% [markdown]
# ### Output

# %%
songs_list = songs.split("\n")
song_split = []
for x in range(len(songs_list)):
    hashtags = []
    song_split.append([])
    for y in range(2):
        song_split[x].append(''.join(e for e in songs_list[x].split(" - ")[y] if e.isalnum()).lower())
    hashtags.append(f"#{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][0]}{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}dancecover")
    hashtags.append(f"#{song_split[x][0]}edit")
    print(" ".join(hashtags))
# Out:
# #jihyo #closer #closerjihyo #jihyocloser #closerdancecover #jihyoedit
# #triplesaaa #generation #generationtriplesaaa #triplesaaageneration #generationdancecover #triplesaaaedit
# #enhypen #criminallove #criminalloveenhypen #enhypencriminallove #criminallovedancecover #enhypenedit
# #evnne #trouble #troubleevnne #evnnetrouble #troubledancecover #evnneedit
# #txt #chasingthatfeeling #chasingthatfeelingtxt #txtchasingthatfeeling #chasingthatfeelingdancecover #txtedit
# #nct127 #factcheck #factchecknct127 #nct127factcheck #factcheckdancecover #nct127edit
# #aespa #drama #dramaaespa #aespadrama #dramadancecover #aespaedit
# #ikon #killingme #killingmeikon #ikonkillingme #killingmedancecover #ikonedit
# #p1harmony #butterfly #butterflyp1harmony #p1harmonybutterfly #butterflydancecover #p1harmonyedit

# %% [markdown]
# ## Hashtag Creator for YT Video + Artist/Title Lister

# %% [markdown]
# ### Input (YT Timestamps)

# %%
raw = """00:00:03 1 OnlyOneOf - dOpamine (Chorus 2) (None)
00:00:46 2 BTS - Mic Drop (Pre-Chorus 1, Chorus 1) (None)
00:01:44 3 Enhypen - Sweet Venom (Chorus 1) (None)
00:02:25 4 Soojin - agassy (Chorus 1) (None)
00:03:04 5 Nct 127 - Fact Check (Chorus 1) (None)
00:03:43 6 Hyuna - I'm not cool (Chorus 1) (None)
00:04:17 7 Triple H - 365 Fresh (Chorus 1) (None)
00:05:11 8 Jennie - Solo (Chorus 3) (None)
00:05:49 9 Le sserafim - Blue flame (Chorus 1) (None)
00:06:40 10 Pentagon - Naughty Boy (Pre-Chorus 1) (None)
00:07:30 11 EXO - The Eve (Pre-Chorus 1, Chorus 1) (None)
00:08:27 12 Ateez - Crazy form (Chorus 1) (None)
00:09:03 13 Viviz - Maniac (Chorus 3) (None)
00:09:54 14 Winner - Really Really (Chorus 1) (None)
00:10:26 15 Stray kids - All in (Dancebreak) (None)
00:11:01 16 P1Harmony - Jump (Dancebreak) (None)
00:24:18 34 New Jeans - Hype Boy (Chorus 1) (None)
00:25:15 35 Kep1er - Back to the City (Chorus 1) (None)
00:25:52 36 KNK - Knock (Chorus 1) (None)
00:26:31 37 Enhypen - Still Monster (Chorus 1) (None)
00:27:13 38 NMIXX - Soñar (Breaker) (Chorus 1) (None)
00:27:45 39 Taemin - Guilty (Pre-Chorus 1) (None)"""

# %% [markdown]
# ### Output

# %% [markdown]
# #### Hashtags for YT Video

# %%
raw_list = raw.split("\n")

export_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_edit = "".join(e for e in artist if e.isalnum()).upper()
    export_list.append(artist_edit)

export_list.sort()
export_list = list(dict.fromkeys(export_list))

artist_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_list.append(artist)

title_list = []
for x in raw_list:
    title = x.split(" - ")[1].split(" (")[0]
    title_list.append(title)

print("#" + " #".join(export_list))
# Out:
# #AESPA #AOA #APINK #ATEEZ #BABYMONSTER #BAE173 #BAEKHYUN #BIGBANG #BLACKPINK #BOA #BOYSPLANET #BTS #CHERRYBULLET #CIX #DREAMCATCHER #ENHYPEN #EUNBI #EVERGLOW #EXID #EXO #GIDLE #GIRLSPLANET999 #HEARTSTEEL #HWASA #HYUNA #IOI #ITZY #IVE #IZONE #JENNIE #JESSI #JHOPE #JIMIN #JUNGKOOK #KAI #KARD #KEP1ER #KINGDOM #KISSOFLIFE #KNK #LEESUHYUN #LESSERAFIM #LIGHTSUM #LOONA #MAMAMOO #MOMOLAND #NCT127 #NCTDREAM #NEWJEANS #NMIXX #OHMYGIRL #ONEPACT #ONEUS #ONLYONEOF #ORANGECARAMEL #ORANGECARAMELL #P1HARMONY #PENTAGON #PURPLEKISS #REDVELVET #RIIZE #SEVENTEEN #SHINEE #SNSD #SOOJIN #STAYC #STRAYKIDS #SUNMI #SUPERM #TAEMIN #TAEYONG #THEBOYZ #TRIPLEH #TROUBLEMAKER #TWICE #TWS #TXT #VCHA #VIVIZ #WANNAONE #WAYV #WINNER #YENA #YUJU #YUTO #ZEROBASEONE

# %% [markdown]
# #### Artist and Title

# %%
print("\n".join(artist_list))
print("\n\n\n\n\n\n")
print("\n".join(title_list))
# Out:
# OnlyOneOf
# BTS
# Enhypen
# Soojin
# Nct 127
# Hyuna
# Triple H
# Jennie
# Le sserafim
# Pentagon
# EXO
# Ateez
# Viviz
# Winner
# Stray kids
# P1Harmony
# Dreamcatcher
# (G)-idle
# Blackpink
# ITZY
# Loona
# jungkook
# TWS
# kep1er
# SHINee
# Itzy
# BigBang
# Sunmi
# TWICE
# NMIXX
# Ateez
# Yuto
# Everglow
# RIIZE
# Aespa
# Red Velvet
# New Jeans
# Nct dream
# Stray Kids
# Taeyong
# Seventeen
# Trouble Maker
# Eunbi
# Yena
# Jessi
# Stayc
# Boa
# girls planet 999
# NMIXX
00:25:15 35 Kep1er - Back to the City (Chorus 1) (None)
00:25:52 36 KNK - Knock (Chorus 1) (None)
00:26:31 37 Enhypen - Still Monster (Chorus 1) (None)
00:27:13 38 NMIXX - Soñar (Breaker) (Chorus 1) (None)
00:27:45 39 Taemin - Guilty (Pre-Chorus 1) (None)
"""

# %% [markdown]
# ### Output

# %%
startTimeSplit = startTime.split(":")
startTimeInSeconds = 0
startTimeInSeconds += int(startTimeSplit[0]) * 60 * 60
startTimeInSeconds += int(startTimeSplit[1]) * 60
startTimeInSeconds += int(startTimeSplit[2])

rawSplit = raw.split("\n")[1:-1]
for x in rawSplit:
    playlistTimeStampInSeconds = 0
    newTimeStampHour = 0
    newTimeStampMinute = 0

    # Remove unnecassary Suffix
    noSuffix = x.rsplit(" (", 2)[0]
    noSuffixSplit = noSuffix.split(" ", 2)

    playlistTimeStampSplit = noSuffixSplit[0].split(":")
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[0]) * 60 * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[1]) * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[2])

    newTimeStampInSeconds = startTimeInSeconds + playlistTimeStampInSeconds

    newTimeStampHour =  math.floor(newTimeStampInSeconds / 3600)
    newTimeStampInSeconds = newTimeStampInSeconds % 3600
    newTimeStampHourString = str(newTimeStampHour).zfill(2)

    newTimeStampMinute =  math.floor(newTimeStampInSeconds / 60)
    newTimeStampInSeconds = newTimeStampInSeconds % 60
    newTimeStampMinuteString = str(newTimeStampMinute).zfill(2)

    newTimeStampSecondString =str(newTimeStampInSeconds).zfill(2)

    newTimeStampString = ":".join([newTimeStampHourString, newTimeStampMinuteString, newTimeStampSecondString])

    print(newTimeStampString + " " + noSuffixSplit[2])
# Out:
# 01:34:22 Bts - Airplane pt.2
# 01:35:20 Baekhyun - Bambi
# 01:36:09 Stray Kids - All in
# 01:36:41 oneus - bbusyeo
# 01:37:18 Orange caramell - My copycat
# 01:38:05 Itzy - Cherry
# 01:38:38 Seventeen - Super
# 01:39:36 WayV - Poppin’ Love
# 01:40:19 snsd - genie
# 01:41:07 Twice - Yes or Yes
# 01:41:53 Yuju - DALALA
# 01:42:42 J Hope - Hope World
# 01:43:16 Jungkook - 3D
# 01:44:00 EXO - Lucky One
# 01:44:48 Red Velvet - Psycho
# 01:45:27 Dreamcatcher - Chase me
# 01:46:07 Momoland - I'm so Hot
# 01:46:50 Twice - Likey
# 01:47:36 NCT Dream - BOOM
# 01:48:25 Stray Kids - The view
# 01:49:20 (G)-IDLE - Super Lady
# 01:49:51 Hwasa - Chili
# 01:50:27 Everglow - Dun Dun
# 01:51:21 Pentagon - Humph
# 01:52:10 lightsum - vivace
# 01:52:59 Itzy - Ringo
# 01:53:45 Ateez - Fireworks (I'm the one)
# 01:54:30 RIIZE - Siren
# 01:55:07 Apink - Dumhdurum
# 01:56:00 THE BOYZ - WATCH IT
# 01:56:36 Blackpink - Pretty Savage
# 01:57:13 Vcha - Ready for the world
# 01:57:53 Stray Kids - Easy
# ...
