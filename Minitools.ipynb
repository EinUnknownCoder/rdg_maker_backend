# %% [markdown]
# # Minitools

# %% [markdown]
# ## Hashtrag Creator for Instagram-/YT-Shorts-/TikTok-Posts

# %% [markdown]
# ### Input

# %%
songs = """JIHYO - Closer
tripleS AAA - Generation
ENHYPEN - Criminal Love
EVNNE - TROUBLE
TXT - Chasing That Feeling
NCT 127 - Fact Check
aespa - Drama
iKON - KILLING ME
P1Harmony - Butterfly"""

# %% [markdown]
# ### Output

# %%
songs_list = songs.split("\n")
song_split = []
for x in range(len(songs_list)):
    hashtags = []
    song_split.append([])
    for y in range(2):
        song_split[x].append(''.join(e for e in songs_list[x].split(" - ")[y] if e.isalnum()).lower())
    hashtags.append(f"#{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][0]}{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}dancecover")
    hashtags.append(f"#{song_split[x][0]}edit")
    print(" ".join(hashtags))
# Out:
# #jihyo #closer #closerjihyo #jihyocloser #closerdancecover #jihyoedit
# #triplesaaa #generation #generationtriplesaaa #triplesaaageneration #generationdancecover #triplesaaaedit
# #enhypen #criminallove #criminalloveenhypen #enhypencriminallove #criminallovedancecover #enhypenedit
# #evnne #trouble #troubleevnne #evnnetrouble #troubledancecover #evnneedit
# #txt #chasingthatfeeling #chasingthatfeelingtxt #txtchasingthatfeeling #chasingthatfeelingdancecover #txtedit
# #nct127 #factcheck #factchecknct127 #nct127factcheck #factcheckdancecover #nct127edit
# #aespa #drama #dramaaespa #aespadrama #dramadancecover #aespaedit
# #ikon #killingme #killingmeikon #ikonkillingme #killingmedancecover #ikonedit
# #p1harmony #butterfly #butterflyp1harmony #p1harmonybutterfly #butterflydancecover #p1harmonyedit

# %% [markdown]
# ## Hashtag Creator for YT Video + Artist/Title Lister

# %% [markdown]
# ### Input (YT Timestamps)

# %%
raw = """00:00:06 1 NMIXX - O.O (Dancebreak) (x.ame.x)
00:00:58 2 Le sserafim - pierrot (Chorus 1) (lqura_ql)
00:02:15 3 Seventeen - Thanks (Chorus 1) (ywavvaa)
00:02:57 4 IVE - Blue blood (Chorus 1) (lini.x.aylin_)
00:03:53 5 Enhypen - 10 months (Chorus 1) (Anyali_45)
00:04:41 6 WJSN - Save me, Save you (Chorus 1) (@Kevin_istalleinezuhause)
00:05:35 7 BigBang - Bang Bang Bang (Chorus 1) (Basic)
00:06:24 8 P1harmony - Sad Song (Chorus 1) (mara.thv)
00:07:35 9 Yena - Wicked Love (Pre Chorus, Chorus 1) (Basic)
00:08:23 10 Twice - The Feels (Chorus 1) (Basic)
00:09:09 11 Ateez - Take me home (Chorus 1) (Alex_is_random._)
00:09:59 12 Red Velvet - Cosmic (Chorus 1) (Basic)
00:10:55 13 Kep1er - Sync Love (Chorus 1) (ilosch_stgt)
00:11:55 14 CIX - THUNDER (Chorus 1) (@acake.dance)
00:12:53 15 JO1 - NewSmile (Chorus 1) (rin_things)
00:13:58 16 Stray Kids - Walkin on Water (Chorus 1) (Lee_h0)
00:14:52 17 Irene & Seulgi - Naughty (Chorus 1) (@yuxchuu)
00:15:43 18 Zerobaseone - Sweat (Chorus 1) (elinaa.pdf)
00:16:32 19 VICTON - Mayday (Chorus 1) (Jess.doesnt.know)
00:17:06 20 &TEAM - deer hunter (Chorus 1) (alfaschicksalynn)
00:18:17 21 NCT 127 - Fact Check (Chorus 1) (Basic)
00:18:53 22 J-hope - Sweet Dreams (Chorus 1, TikTok Challenge) (@evelin_e.stg)
00:19:35 23 Enhypen - Sacrifice (Eat me up) (Pre Chorus, Chorus 1) (Basic)
00:20:34 24 RIIZE - Get A guitar (Chorus 2, Dancebreak) (02.d3em)
00:22:08 25 K/DA - POP/STARS (Chorus 1) (zoeyruiiz)
00:23:07 26 EXO-K - History (Chorus 1) (@_adri_2210)
00:23:55 27 Meovv - Meow (Chorus 1) (Basic)
00:24:41 28 BTS - DNA (Chorus 1) (jakeoscarh)
00:25:28 29 Ateez - Bouncy (Chorus 1) (ismail_.635)
00:26:21 30 Stray Kids - Burnin' Tires (Chorus 1) (New)
00:27:04 31 Got7 - Python (Chorus 1) (@Jeonghansholyspirit)
00:28:21 32 B.I - Keep me up (Chorus 2) (@_ggowjou_)
00:29:30 33 Stray Kids - Case 143 (Chorus 1) (Basic)
00:30:13 34 Troublemaker - Now (Chorus 1) (lini.x.aylin_)
00:31:09 35 aespa - Drama (Chorus 1) (Basic)"""

# %% [markdown]
# ### Output

# %% [markdown]
# #### Hashtags for YT Video

# %%
raw_list = raw.split("\n")

export_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_edit = "".join(e for e in artist if e.isalnum()).upper()
    export_list.append(artist_edit)

export_list.sort()
export_list = list(dict.fromkeys(export_list))

artist_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_list.append(artist)

title_list = []
for x in raw_list:
    title = x.split(" - ")[1].split(" (")[0]
    title_list.append(title)

print("#" + " #".join(export_list))
# Out:
# #8TURN #AESPA #ALLHOURS #ATEEZ #BADVILLAIN #BAEKHYUN #BDC #BI #BIGBANG #BLACKPINK #BTS #CHANGBIN #CHUNGHA #CIX #CRAVITY #DEARALICE #ELRIS #ENHYPEN #EVERGLOW #EXID #EXOK #GDRAGON #GIDLE #GIRLSGENERATION #GOT7 #HEARTS2HEARTS #HOSHIWOOZI #HYOLYN #IN #IRENESEULGI #ITZY #IVE #JENNIE #JHOPE #JIHYO #JIMIN #JO1 #JUNGKOOK #KAI #KARD #KDA #KEP1ER #KISSOFLIFE #LESSERAFIM #LISA #LOONA #LUCAS #MEOVV #MINNIE #MONSTAX #MYTRO #NCT127 #NCTDREAM #NEWJEANS #NMIXX #NOUERA #P1HARMONY #PD48 #PINKFANTASY #PLAVE #REDVELVET #RESCENE #RIIZE #SEVENTEEN #SF9 #STAYC #STRAYKIDS #SUPERM #TEAM #TEN #THE8 #TROUBLEMAKER #TWICE #TWS #TXT #VICTON #WAKER #WAYV #WEEEKLY #WJSN #WONDERGIRLS #WONHO #XIKERS #YEJI #YENA #ZEROBASEONE

# %% [markdown]
# #### Artist and Title

# %%
print("\n".join(artist_list))
print("\n\n\n\n\n\n")
print("\n".join(title_list))
# Out:
# Twice
# Jimin
# STAYC
# Yuto Adachi
# Stray Kids
# (G)I-DLE
# IVE
# LE SSERAFIM
# Got7
# (G)I-DLE
# f(x)
# NiziU
# 4Minute
# CRAVITY
# Kard
# Enhypen
# Red Velvet
# aespa
# Babymonster
# Dreamcatcher
# LE SSERAFIM
# Mamamoo
# Pentagon
# Ateez
# E'last
# Seventeen
# Itzy
# NMIXX
# Hwasa
# Taemin
# Twice
# 2PM
# (G)I-DLE
# Kep1er
# Blackpink
# TEN
# Exo
# NCT Wish
# Xdinary Heroes
# Alexa
# Brave Girls
# Stray Kids
# Billlie
# NCT 127
# Everglow
# Oneus
# aespa
# Iz*one
# 7 LOVE Minutes
# Itzy
# Chung Ha
# Enhypen
# Ghost9
# The Boyz
# VERIVERY
# Twice
# Weeekly
# (G)I-DLE
# Lee Suhyun
# Blackpink
# CRAVITY
# Produce 48
# Mamaoo
# Apink
# Itzy
# EXO
# Everglow
# TEN
# Stray Kids
# The Boyz
# Kep1er
# aespa
# NewJeans
# Enhypen
# OnlyOneOf
# VIVIZ
# P1harmony
# Girls Generation
# Kard
# BTS
# IZ*ONE
# Twice
# Enhypen
# LE SSERAFIM
# Stray Kids
# Itzy
# Somi
# Blackpink
# Babymonster
# Enhypen
# LE SSERAFIM
# JINI
# Red Velvet
# NMIXX
# ZEROBASEONE
# NMIXX
# (G)I-DLE
# Hinapia
# ...

# %% [markdown]
# ## Timestamp Creator for YT Video

# %% [markdown]
# ### Input

# %%
import math

startTime = "00:00:06"

raw = """
00:00:06 1 NMIXX - O.O (Dancebreak) (x.ame.x)
00:00:58 2 Le sserafim - pierrot (Chorus 1) (lqura_ql)
00:02:15 3 Seventeen - Thanks (Chorus 1) (ywavvaa)
00:02:57 4 IVE - Blue blood (Chorus 1) (lini.x.aylin_)
00:03:53 5 Enhypen - 10 months (Chorus 1) (Anyali_45)
00:04:41 6 WJSN - Save me, Save you (Chorus 1) (@Kevin_istalleinezuhause)
00:05:35 7 BigBang - Bang Bang Bang (Chorus 1) (Basic)
00:06:24 8 P1harmony - Sad Song (Chorus 1) (mara.thv)
00:07:35 9 Yena - Wicked Love (Pre Chorus, Chorus 1) (Basic)
00:08:23 10 Twice - The Feels (Chorus 1) (Basic)
00:09:09 11 Ateez - Take me home (Chorus 1) (Alex_is_random._)
00:09:59 12 Red Velvet - Cosmic (Chorus 1) (Basic)
00:10:55 13 Kep1er - Sync Love (Chorus 1) (ilosch_stgt)
00:11:55 14 CIX - THUNDER (Chorus 1) (@acake.dance)
00:12:53 15 JO1 - NewSmile (Chorus 1) (rin_things)
00:13:58 16 Stray Kids - Walkin on Water (Chorus 1) (Lee_h0)
00:14:52 17 Irene & Seulgi - Naughty (Chorus 1) (@yuxchuu)
00:15:43 18 Zerobaseone - Sweat (Chorus 1) (elinaa.pdf)
00:16:32 19 VICTON - Mayday (Chorus 1) (Jess.doesnt.know)
00:17:06 20 &TEAM - deer hunter (Chorus 1) (alfaschicksalynn)
00:18:17 21 NCT 127 - Fact Check (Chorus 1) (Basic)
00:18:53 22 J-hope - Sweet Dreams (Chorus 1, TikTok Challenge) (@evelin_e.stg)
00:19:35 23 Enhypen - Sacrifice (Eat me up) (Pre Chorus, Chorus 1) (Basic)
00:20:34 24 RIIZE - Get A guitar (Chorus 2, Dancebreak) (02.d3em)
00:22:08 25 K/DA - POP/STARS (Chorus 1) (zoeyruiiz)
00:23:07 26 EXO-K - History (Chorus 1) (@_adri_2210)
00:23:55 27 Meovv - Meow (Chorus 1) (Basic)
00:24:41 28 BTS - DNA (Chorus 1) (jakeoscarh)
00:25:28 29 Ateez - Bouncy (Chorus 1) (ismail_.635)
00:26:21 30 Stray Kids - Burnin' Tires (Chorus 1) (New)
00:27:04 31 Got7 - Python (Chorus 1) (@Jeonghansholyspirit)
00:28:21 32 B.I - Keep me up (Chorus 2) (@_ggowjou_)
00:29:30 33 Stray Kids - Case 143 (Chorus 1) (Basic)
00:30:13 34 Troublemaker - Now (Chorus 1) (lini.x.aylin_)
00:31:09 35 aespa - Drama (Chorus 1) (Basic)
"""

# %% [markdown]
# ### Output

# %%
startTimeSplit = startTime.split(":")
startTimeInSeconds = 0
startTimeInSeconds += int(startTimeSplit[0]) * 60 * 60
startTimeInSeconds += int(startTimeSplit[1]) * 60
startTimeInSeconds += int(startTimeSplit[2])

rawSplit = raw.split("\n")[1:-1]
for x in rawSplit:
    playlistTimeStampInSeconds = 0
    newTimeStampHour = 0
    newTimeStampMinute = 0

    # Remove unnecassary Suffix
    noSuffix = x.rsplit(" (", 2)[0]
    noSuffixSplit = noSuffix.split(" ", 2)

    playlistTimeStampSplit = noSuffixSplit[0].split(":")
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[0]) * 60 * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[1]) * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[2])

    newTimeStampInSeconds = startTimeInSeconds + playlistTimeStampInSeconds

    newTimeStampHour =  math.floor(newTimeStampInSeconds / 3600)
    newTimeStampInSeconds = newTimeStampInSeconds % 3600
    newTimeStampHourString = str(newTimeStampHour).zfill(2)

    newTimeStampMinute =  math.floor(newTimeStampInSeconds / 60)
    newTimeStampInSeconds = newTimeStampInSeconds % 60
    newTimeStampMinuteString = str(newTimeStampMinute).zfill(2)

    newTimeStampSecondString =str(newTimeStampInSeconds).zfill(2)

    newTimeStampString = ":".join([newTimeStampHourString, newTimeStampMinuteString, newTimeStampSecondString])

    print(newTimeStampString + " " + noSuffixSplit[2])
# Out:
# 00:00:12 NMIXX - O.O
# 00:01:04 Le sserafim - pierrot
# 00:02:21 Seventeen - Thanks
# 00:03:03 IVE - Blue blood
# 00:03:59 Enhypen - 10 months
# 00:04:47 WJSN - Save me, Save you
# 00:05:41 BigBang - Bang Bang Bang
# 00:06:30 P1harmony - Sad Song
# 00:07:41 Yena - Wicked Love
# 00:08:29 Twice - The Feels
# 00:09:15 Ateez - Take me home
# 00:10:05 Red Velvet - Cosmic
# 00:11:01 Kep1er - Sync Love
# 00:12:01 CIX - THUNDER
# 00:12:59 JO1 - NewSmile
# 00:14:04 Stray Kids - Walkin on Water
# 00:14:58 Irene & Seulgi - Naughty
# 00:15:49 Zerobaseone - Sweat
# 00:16:38 VICTON - Mayday
# 00:17:12 &TEAM - deer hunter
# 00:18:23 NCT 127 - Fact Check
# 00:18:59 J-hope - Sweet Dreams
# 00:19:41 Enhypen - Sacrifice (Eat me up)
# ...

# %%
caption_text = """1
00:00:00,000 --> 00:00:09,000
RDG Start\n\n"""
count = 0
timestamp_old = rawSplit[0].split(" ")[0]
for x in range(len(rawSplit)-1):
    caption_text += f"{x+1}\n"

    timestamp_next = rawSplit[x+1].split(" ")[0]
    caption_text += f"{timestamp_old},000 --> {timestamp_next},000\n"
    timestamp_old = timestamp_next

    # Remove unnecassary Suffix
    noSuffixSplit = rawSplit[x].split(" ", 1)
    caption_text += f"{noSuffixSplit[1]}\n\n".upper()
    
print(caption_text)
# Out:
# 1
# 00:00:00,000 --> 00:00:09,000
# RDG Start
#
# 1
# 00:00:12,000 --> 00:01:04,000
# NMIXX - O.O
#
# 2
# 00:01:04,000 --> 00:02:21,000
# LE SSERAFIM - PIERROT
#
# 3
# 00:02:21,000 --> 00:03:03,000
# SEVENTEEN - THANKS
#
# 4
# 00:03:03,000 --> 00:03:59,000
# IVE - BLUE BLOOD
#
# 5
# 00:03:59,000 --> 00:04:47,000
# ENHYPEN - 10 MONTHS
#
# 6
# 00:04:47,000 --> 00:05:41,000
# WJSN - SAVE ME, SAVE YOU
#
# 7
# 00:05:41,000 --> 00:06:30,000
# BIGBANG - BANG BANG BANG
#
# 8
# 00:06:30,000 --> 00:07:41,000
# P1HARMONY - SAD SONG
#
# 9
# 00:07:41,000 --> 00:08:29,000
# YENA - WICKED LOVE
#
# 10
# 00:08:29,000 --> 00:09:15,000
# TWICE - THE FEELS
#
# 11
# 00:09:15,000 --> 00:10:05,000
# ATEEZ - TAKE ME HOME
#
# 12
# 00:10:05,000 --> 00:11:01,000
# RED VELVET - COSMIC
#
# 13
# 00:11:01,000 --> 00:12:01,000
# KEP1ER - SYNC LOVE
#
# 14
# 00:12:01,000 --> 00:12:59,000
# CIX - THUNDER
#
# 15
# 00:12:59,000 --> 00:14:04,000
# JO1 - NEWSMILE
#
# 16
# 00:14:04,000 --> 00:14:58,000
# ...

# %% [markdown]
# # Playground

# %%
import json
import yt_dlp

URL = 'https://www.youtube.com/watch?v=BaW_jenozKc'

# ℹ️ See help(yt_dlp.YoutubeDL) for a list of available options and public functions
ydl_opts = {}
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(URL, download=False)

    # ℹ️ ydl.sanitize_info makes the info json-serializable
    print(info['title'])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BaW_jenozKc
# [youtube] BaW_jenozKc: Downloading webpage
# [youtube] BaW_jenozKc: Downloading ios player API JSON
# [youtube] BaW_jenozKc: Downloading android player API JSON
# ERROR: [youtube] BaW_jenozKc: Video unavailable. This video has been removed by the uploader
# ---------------------------------------------------------------------------
# ExtractorError                            Traceback (most recent call last)
# File d:\Documents\Code\rdg_maker_backend\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1594, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1593 try:
# -> 1594     return func(self, *args, **kwargs)
#    1595 except (DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#
# File d:\Documents\Code\rdg_maker_backend\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1729, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1728 try:
# ...

# %%
raw = """00:00:03 1 tripleS - Girls never die (Chorus 2) (Mel)
00:00:36 2 TXT - Chasing that Feeling (Chorus) (Basic)
00:01:11 3 Iz*One - Panorama (Chorus) (Alissa)
00:01:57 4 Ill'it - Magnetic (Chorus) (Basic)
00:02:37 5 StrayKids - God's Menu (Pre-Chorus, Chorus) (Basic)
00:03:21 6 Han Seungwoo - Sacrifice (Chorus 2) (Ace)
00:04:01 7 EXO - Ooh La La La (Chorus) (Adriana)
00:04:34 8 Kiss of Life - Midas Touch (Pre-Chorus, Chorus) (Milla)
00:05:06 9 &Team - Samidare (Chorus) (Salina)
00:05:58 10 Ateez - Horizon (Chorus) (Yuki)
00:06:26 11 Billie - Gingamingayo (Chorus) (Yuki)
00:07:17 12 (G)-idle - Wife (Pre-Chorus, Chorus 2) (Lilly)
00:08:00 13 NCT U - Baby don't stop (Chorus) (Mel)
00:08:34 14 Loossemble - ‘Girls’ Night’ (Dancebreak) (Salina)
00:09:28 15 Twice - MORE & MORE (Dancebreak) (Ines)
00:10:15 16 Aespa - Drama (Chorus) (Basic)
00:10:56 17 Enhypen - Bite me (Dancebreak) (Ivan)
00:11:48 18 Bts - Fire (Chorus) (Thony)
00:12:32 19 Everglow - Bon Bon Chocolat (Chorus) (Basic)
00:13:19 20 KARD - Icky (Chorus) (Basic)
00:13:55 21 JungKook - Standing Next To You (Dancebreak) (Basic)
00:14:42 22 IVE - I Am (Chorus) (Basic)
00:15:08 23 Xikers - Tricky House (Dancebreak) (Basic)
00:15:38 24 Taemin - Advice (Chorus) (Jake)
00:16:27 25 Enhypen - mixed up (Pre-Chorus, Chorus) (Marry)
00:17:13 26 Seventeen - Left & Right (Chorus) (Ace)
00:17:57 27 PSY - Gangnam Style (Chorus) (Basic)
00:18:35 28 Boynextdoor - Earth, Wind & Fire (Chorus) (Milla)
00:19:07 29 VCHA - Only One (Pre-Chorus, Chorus) (Alessa)
00:19:59 30 Itzy - Loco (Chorus) (Basic)
00:20:36 31 Chung Ha  - Snapping (Chorus) (Basic)
00:21:20 32 Soñar (Breaker) - NMIXX (Chorus 2, Dancebreak) (Lera)
00:22:33 33 WayV - Regular (Chorus) (Ascela)
00:23:12 34 NCT 127 - Kick it (Intro) (Basic)
00:23:49 35 OMEGAX - JUNK FOOD (Pre-Chorus, Chorus) (Marry)
00:24:23 36 Babymonster - Sheesh (Pre-Chorus, Chorus) (Hanna)"""

# %%
arr = raw.split("\n")
sec = 0
for x in arr:
    temp = x.split(" ")[0].split(":")
    sec = int(temp[2]) + (int(temp[1]) * 60) + (int(temp[0]) * 360)
    print(sec)
# Out:
# 3
# 36
# 71
# 117
# 157
# 201
# 241
# 274
# 306
# 358
# 386
# 437
# 480
# 514
# 568
# 615
# 656
# 708
# 752
# 799
# 835
# 882
# 908
# 938
# 987
# 1033
# 1077
# 1115
# 1147
# 1199
# 1236
# 1280
# 1353
# 1392
# 1429
# 1463
