# %% [markdown]
# # Minitools

# %% [markdown]
# ## Hashtrag Creator for Instagram-/YT-Shorts-/TikTok-Posts

# %% [markdown]
# ### Input

# %%
songs = """JIHYO - Closer
tripleS AAA - Generation
ENHYPEN - Criminal Love
EVNNE - TROUBLE
TXT - Chasing That Feeling
NCT 127 - Fact Check
aespa - Drama
iKON - KILLING ME
P1Harmony - Butterfly"""

# %% [markdown]
# ### Output

# %%
songs_list = songs.split("\n")
song_split = []
for x in range(len(songs_list)):
    hashtags = []
    song_split.append([])
    for y in range(2):
        song_split[x].append(''.join(e for e in songs_list[x].split(" - ")[y] if e.isalnum()).lower())
    hashtags.append(f"#{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}{song_split[x][0]}")
    hashtags.append(f"#{song_split[x][0]}{song_split[x][1]}")
    hashtags.append(f"#{song_split[x][1]}dancecover")
    hashtags.append(f"#{song_split[x][0]}edit")
    print(" ".join(hashtags))
# Out:
# #jihyo #closer #closerjihyo #jihyocloser #closerdancecover #jihyoedit
# #triplesaaa #generation #generationtriplesaaa #triplesaaageneration #generationdancecover #triplesaaaedit
# #enhypen #criminallove #criminalloveenhypen #enhypencriminallove #criminallovedancecover #enhypenedit
# #evnne #trouble #troubleevnne #evnnetrouble #troubledancecover #evnneedit
# #txt #chasingthatfeeling #chasingthatfeelingtxt #txtchasingthatfeeling #chasingthatfeelingdancecover #txtedit
# #nct127 #factcheck #factchecknct127 #nct127factcheck #factcheckdancecover #nct127edit
# #aespa #drama #dramaaespa #aespadrama #dramadancecover #aespaedit
# #ikon #killingme #killingmeikon #ikonkillingme #killingmedancecover #ikonedit
# #p1harmony #butterfly #butterflyp1harmony #p1harmonybutterfly #butterflydancecover #p1harmonyedit

# %% [markdown]
# ## Hashtag Creator for YT Video + Artist/Title Lister

# %% [markdown]
# ### Input (YT Timestamps)

# %%
raw = """00:00:03 1 ARTMS - Virtual Angel (Chorus 1) (Top 50)
00:01:02 2 NCT 127 - 2 Baddies (Chorus 1) (Top 50)
00:01:47 3 Jimin - Face Off (TikTok Challenge) (Top 50)
00:02:19 4 xikers - red sun (Dancebreak) (Top 50)
00:03:18 5 EXO - Obsession (Chorus 1) (Top 50)
00:04:06 6 Victon - Flip a coin (Chorus 1) (Top 50)
00:04:53 7 Twice - The Feels (Chorus 1) (Basic)
00:05:35 8 NATTY - Sugarcoat (Chorus 1) (Top 50)
00:06:17 9 P1harmony - Back down (Chorus 1) (Top 50)
00:06:55 10 Seventeen - Spell (Chorus 1) (Top 50)
00:07:31 11 Stray Kids - Freeze (Chorus 1) (Top 50)
00:08:12 12 Girl's Day - I'll be yours (Chorus 1) (Top 50)
00:08:49 13 Kiss of Life - Nobody Knows (Prechorus 1) (Top 50)
00:09:40 14 Ab6ix - Breathe (Chorus 1) (Top 50)
00:10:19 15 New Jeans - Supershy (Chorus 1) (Basic)
    export_list.append(artist_edit)

export_list.sort()
export_list = list(dict.fromkeys(export_list))

artist_list = []
for x in raw_list:
    artist = " ".join(x.split(" - ")[0].split(" ")[2:])
    artist_list.append(artist)

title_list = []
for x in raw_list:
    title = x.split(" - ")[1].split(" (")[0]
    title_list.append(title)

print("#" + " #".join(export_list))
# Out:
# #AB6IX #AESPA #AOA #ARTMS #ATEEZ #BIGBANG #BILLLIE #BLACKPINK #BOYSPLANET #BTS #CHUU #CLC #DREAMCATCHER #EL7ZUP #ENHYPEN #EVERGLOW #EXID #EXO #FROMIS9 #GIDLE #GIRLSDAY #GOT7 #ILAND2 #ILAND2NA #ILLIT #ITZY #JESSI #JIMIN #JUN #KAI #KARD #KDA #KEP1ER #KISSOFLIFE #LESSERAFIM #LISA #MAMAMOO #MCND #MOMOLAND #MONSTAX #NATTY #NAYEON #NCT #NCT127 #NCTU #NEWJEANS #NMIXX #NOWADAYS #ONEPACT #ONLYONEOF #ORANGECARAMEL #P1HARMONY #PIXY #REDVELVET #RIIZE #SAMUEL #SEVENTEEN #SNSD #SOLAR #STAYC #STRAYKIDS #SUNMI #TAEMIN #TAEYANG #TEAM #TEMPEST #THEKINGDOM #TRIBE #TROUBLEMAKER #TWICE #TWS #UNIS #VICTON #WAKER #WAYV #WHIB #WINNER #WOOAH #XG #XIKERS #YOUHA #ZEROBASEONE

# %% [markdown]
# #### Artist and Title

# %%
print("\n".join(artist_list))
print("\n\n\n\n\n\n")
print("\n".join(title_list))
# Out:
# Twice
# Jimin
# STAYC
# Yuto Adachi
# Stray Kids
# (G)I-DLE
# IVE
# LE SSERAFIM
# Got7
# (G)I-DLE
# f(x)
# NiziU
# 4Minute
# CRAVITY
# Kard
# Enhypen
# Red Velvet
# aespa
# Babymonster
# Dreamcatcher
# LE SSERAFIM
# Mamamoo
# Pentagon
# Ateez
# E'last
# Seventeen
# Itzy
# NMIXX
# Hwasa
# Taemin
# Twice
# 2PM
# (G)I-DLE
# Kep1er
# Blackpink
# TEN
# Exo
# NCT Wish
# Xdinary Heroes
# Alexa
# Brave Girls
# Stray Kids
# Billlie
# NCT 127
# Everglow
# Oneus
# aespa
# Iz*one
# 7 LOVE Minutes
# Itzy
# Chung Ha
# Enhypen
# Ghost9
# The Boyz
# VERIVERY
# Twice
# Weeekly
# (G)I-DLE
# Lee Suhyun
# Blackpink
# CRAVITY
# Produce 48
# Mamaoo
# Apink
# Itzy
# EXO
# Everglow
# TEN
# Stray Kids
# The Boyz
# Kep1er
# aespa
# NewJeans
# Enhypen
# OnlyOneOf
# VIVIZ
# P1harmony
# Girls Generation
# Kard
# BTS
# IZ*ONE
# Twice
# Enhypen
# LE SSERAFIM
# Stray Kids
# Itzy
# Somi
# Blackpink
# Babymonster
# Enhypen
# LE SSERAFIM
# JINI
# Red Velvet
# NMIXX
# ZEROBASEONE
# NMIXX
# (G)I-DLE
# Hinapia
# ...

# %% [markdown]
# ## Timestamp Creator for YT Video

# %% [markdown]
# ### Input

# %%
import math

startTime = "01:23:19"

raw = """
00:00:03 1 Ateez - IT’s you (Chorus 1) (Top 50)
00:00:49 2 NMIXX - Soñar (Breaker) (Dancebreak) (Top 50)
00:02:05 3 CLC - Black Dress (Chorus 1) (Top 50)
00:03:00 4 ZEROBASEONE - SWEAT (Chorus 1) (Top 50)
00:03:42 5 Samuel - YEH! YEH! (Chorus 1) (Top 50)
00:04:25 6 SOLAR - Colors (Verse 2, Pre-Chorus 2, Chorus 3, Post-Chorus 2) (Popular Vote)
00:05:42 7 BigBang - Bang Bang Bang (Chorus 1) (Basic)
00:06:27 8 Monsta X - Gambler (Chorus 1) (Top 50)
00:07:37 9 taeyang - shoong (Chorus 2) (Top 50)
00:08:32 10 El7z up - Cheeky (Chorus 1) (Top 50)
00:09:31 11 RIIZE - Honestly (Last Chorus) (Top 50)
00:10:13 12 KAI - Peaches (Chorus 1) (Top 50)
00:11:00 13 Boys planet - Here I am (Chorus 1) (Top 50)
00:12:12 14 I-LAND 2 - Final Love Song (Chorus 1, Pre-Chorus) (Top 50)
00:12:46 15 Whib - Kick it (Post Chorus) (Top 50)
00:13:23 16 Kep1er - Shooting Star (Chorus 1) (Top 50)
00:14:07 17 Lisa - rockstar (Chorus 1) (Top 50)
00:14:33 18 Itzy - Loco (Pre-Chorus 1, Chorus 1) (Basic)
00:15:42 19 Jessi - Zoom (Chorus 1) (Basic)
00:16:15 20 EXID - I love you (Chorus 1) (Basic)
00:17:18 21 New jeans - How sweet (Chorus 1) (Top 50)
00:18:09 22 enhypen - sacrifice (Chorus 1, pre chorus) (Top 50)
00:19:15 23 Stray Kids - S-class (Dancebreak) (Top 50)
00:20:36 24 Gidle - Queencard (Chorus 1) (Basic)
00:21:24 25 UNIS - Superwoman (Chorus 1) (Popular Vote)
00:22:18 26 stray kids - hall of fame (Chorus 1) (Top 50, Playlist 4)
00:23:03 27 xikers - red sun (Chorus 1) (Top 50)
00:23:52 28 Trouble Maker - Trouble Maker (Chorus 1, Verse 1 + Chorus 1) (Popular Vote)
00:25:08 29 Orange Caramel - My Copycat (Chorus 2) (Top 50)
00:26:13 30 Red Velvet - Cosmic (Chorus 1) (Top 50)
00:27:00 31 AOA - Mini Skirt (Chorus 1) (Top 50)
00:27:42 32 NCT - Smoothie (Chorus 1) (Top 50)
00:28:13 33 Kiss of Life - Sticky (Chorus 1) (Popular Vote, Playlist 4)
00:28:53 34 Stray Kids - Chk Chk Boom (Chorus 1) (Fresh Release)
"""

# %% [markdown]
# ### Output

# %%
startTimeSplit = startTime.split(":")
startTimeInSeconds = 0
startTimeInSeconds += int(startTimeSplit[0]) * 60 * 60
startTimeInSeconds += int(startTimeSplit[1]) * 60
startTimeInSeconds += int(startTimeSplit[2])

rawSplit = raw.split("\n")[1:-1]
for x in rawSplit:
    playlistTimeStampInSeconds = 0
    newTimeStampHour = 0
    newTimeStampMinute = 0

    # Remove unnecassary Suffix
    noSuffix = x.rsplit(" (", 2)[0]
    noSuffixSplit = noSuffix.split(" ", 2)

    playlistTimeStampSplit = noSuffixSplit[0].split(":")
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[0]) * 60 * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[1]) * 60
    playlistTimeStampInSeconds += int(playlistTimeStampSplit[2])

    newTimeStampInSeconds = startTimeInSeconds + playlistTimeStampInSeconds

    newTimeStampHour =  math.floor(newTimeStampInSeconds / 3600)
    newTimeStampInSeconds = newTimeStampInSeconds % 3600
    newTimeStampHourString = str(newTimeStampHour).zfill(2)

    newTimeStampMinute =  math.floor(newTimeStampInSeconds / 60)
    newTimeStampInSeconds = newTimeStampInSeconds % 60
    newTimeStampMinuteString = str(newTimeStampMinute).zfill(2)

    newTimeStampSecondString =str(newTimeStampInSeconds).zfill(2)

    newTimeStampString = ":".join([newTimeStampHourString, newTimeStampMinuteString, newTimeStampSecondString])

    print(newTimeStampString + " " + noSuffixSplit[2])
# Out:
# 01:23:22 Ateez - IT’s you
# 01:24:08 NMIXX - Soñar (Breaker)
# 01:25:24 CLC - Black Dress
# 01:26:19 ZEROBASEONE - SWEAT
# 01:27:01 Samuel - YEH! YEH!
# 01:27:44 SOLAR - Colors
# 01:29:01 BigBang - Bang Bang Bang
# 01:29:46 Monsta X - Gambler
# 01:30:56 taeyang - shoong
# 01:31:51 El7z up - Cheeky
# 01:32:50 RIIZE - Honestly
# 01:33:32 KAI - Peaches
# 01:34:19 Boys planet - Here I am
# 01:35:31 I-LAND 2 - Final Love Song
# 01:36:05 Whib - Kick it
# 01:36:42 Kep1er - Shooting Star
# 01:37:26 Lisa - rockstar
# 01:37:52 Itzy - Loco
# 01:39:01 Jessi - Zoom
# 01:39:34 EXID - I love you
# 01:40:37 New jeans - How sweet
# 01:41:28 enhypen - sacrifice
# 01:42:34 Stray Kids - S-class
# 01:43:55 Gidle - Queencard
# 01:44:43 UNIS - Superwoman
# 01:45:37 stray kids - hall of fame
# 01:46:22 xikers - red sun
# 01:47:11 Trouble Maker - Trouble Maker
# 01:48:27 Orange Caramel - My Copycat
# 01:49:32 Red Velvet - Cosmic
# 01:50:19 AOA - Mini Skirt
# 01:51:01 NCT - Smoothie
# ...

# %% [markdown]
# # Playground

# %%
import json
import yt_dlp

URL = 'https://www.youtube.com/watch?v=BaW_jenozKc'

# ℹ️ See help(yt_dlp.YoutubeDL) for a list of available options and public functions
ydl_opts = {}
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(URL, download=False)

    # ℹ️ ydl.sanitize_info makes the info json-serializable
    print(info['title'])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BaW_jenozKc
# [youtube] BaW_jenozKc: Downloading webpage
# [youtube] BaW_jenozKc: Downloading ios player API JSON
# [youtube] BaW_jenozKc: Downloading android player API JSON
# WARNING: [youtube] Skipping player responses from android clients (got player responses for video "aQvGIIdgFDM" instead of "BaW_jenozKc")
# [youtube] BaW_jenozKc: Downloading m3u8 information
# youtube-dl test video "'/\ä↭𝕐

# %%
raw = """00:00:03 1 tripleS - Girls never die (Chorus 2) (Mel)
00:00:36 2 TXT - Chasing that Feeling (Chorus) (Basic)
00:01:11 3 Iz*One - Panorama (Chorus) (Alissa)
00:01:57 4 Ill'it - Magnetic (Chorus) (Basic)
00:02:37 5 StrayKids - God's Menu (Pre-Chorus, Chorus) (Basic)
00:03:21 6 Han Seungwoo - Sacrifice (Chorus 2) (Ace)
00:04:01 7 EXO - Ooh La La La (Chorus) (Adriana)
00:04:34 8 Kiss of Life - Midas Touch (Pre-Chorus, Chorus) (Milla)
00:05:06 9 &Team - Samidare (Chorus) (Salina)
00:05:58 10 Ateez - Horizon (Chorus) (Yuki)
00:06:26 11 Billie - Gingamingayo (Chorus) (Yuki)
00:07:17 12 (G)-idle - Wife (Pre-Chorus, Chorus 2) (Lilly)
00:08:00 13 NCT U - Baby don't stop (Chorus) (Mel)
00:08:34 14 Loossemble - ‘Girls’ Night’ (Dancebreak) (Salina)
00:09:28 15 Twice - MORE & MORE (Dancebreak) (Ines)
00:10:15 16 Aespa - Drama (Chorus) (Basic)
00:10:56 17 Enhypen - Bite me (Dancebreak) (Ivan)
00:11:48 18 Bts - Fire (Chorus) (Thony)
00:12:32 19 Everglow - Bon Bon Chocolat (Chorus) (Basic)
00:13:19 20 KARD - Icky (Chorus) (Basic)
00:13:55 21 JungKook - Standing Next To You (Dancebreak) (Basic)
00:14:42 22 IVE - I Am (Chorus) (Basic)
00:15:08 23 Xikers - Tricky House (Dancebreak) (Basic)
00:15:38 24 Taemin - Advice (Chorus) (Jake)
00:16:27 25 Enhypen - mixed up (Pre-Chorus, Chorus) (Marry)
00:17:13 26 Seventeen - Left & Right (Chorus) (Ace)
00:17:57 27 PSY - Gangnam Style (Chorus) (Basic)
00:18:35 28 Boynextdoor - Earth, Wind & Fire (Chorus) (Milla)
00:19:07 29 VCHA - Only One (Pre-Chorus, Chorus) (Alessa)
00:19:59 30 Itzy - Loco (Chorus) (Basic)
00:20:36 31 Chung Ha  - Snapping (Chorus) (Basic)
00:21:20 32 Soñar (Breaker) - NMIXX (Chorus 2, Dancebreak) (Lera)
00:22:33 33 WayV - Regular (Chorus) (Ascela)
00:23:12 34 NCT 127 - Kick it (Intro) (Basic)
00:23:49 35 OMEGAX - JUNK FOOD (Pre-Chorus, Chorus) (Marry)
00:24:23 36 Babymonster - Sheesh (Pre-Chorus, Chorus) (Hanna)"""

# %%
arr = raw.split("\n")
sec = 0
for x in arr:
    temp = x.split(" ")[0].split(":")
    sec = int(temp[2]) + (int(temp[1]) * 60) + (int(temp[0]) * 360)
    print(sec)
# Out:
# 3
# 36
# 71
# 117
# 157
# 201
# 241
# 274
# 306
# 358
# 386
# 437
# 480
# 514
# 568
# 615
# 656
# 708
# 752
# 799
# 835
# 882
# 908
# 938
# 987
# 1033
# 1077
# 1115
# 1147
# 1199
# 1236
# 1280
# 1353
# 1392
# 1429
# 1463
